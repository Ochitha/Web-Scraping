# %%
import requests

# Making a GET request
r = requests.get('https://www.vallibelfinance.com/product/fixed-deposits')

# check status code for response received
# success code - 200
print(r)

# print content of request
print(r.content)
# Out:
# <Response [200]>
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n\n\t<title>Vallibel Finance | Fixed Deposit Rates | Interest Rates</title>\n\t<meta name="keywords" content="Fixed Deposits | Fixed Deposit Rates | Interest Rates">\n    <meta name="description" content="Fixed Deposits. Your return on investment for the Fixed Deposits and capital is guaranteed. Attractive Fixed Deposit Rates. Pre-approved Loan against Fixed Deposit and interest charged only on amount used.">\n\n <meta charset="utf-8">\r\n\r\n\r\n<meta name="csrf-token" content="snSRpLZ96d1wvNZovwjXDKSk7Ew3PuryRQbNjL7i" />\r\n<meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" />\r\n\r\n<meta name="format-detection" content="telephone=no" />\r\n\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\r\n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\r\n\r\n\r\n<link href="https://fonts.googleapis.com/css?family=Roboto:100,300,400,500,700,900" rel="stylesheet">\r\n\r\n<link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800" rel="stylesheet">\r\n\r\n\r\n\r\n<link href="https://www.vallibelfinance.com/site/css/bootstrap.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link rel="stylesheet" href="https://www.vallibelfinance.com/site/css/font-awesome.min.css">\r\n\r\n<link href="https://www.vallibelfinance.com/site/css/master.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link href="https://www.vallibelfinance.com/site/css/style.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link href="https://www.vallibelfinance.com/site/css/reset.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link href="https://www.vallibelfinance.com/site/css/charts.css" rel="stylesheet" type="text/css"/>\r\n\r\n\r\n<link href="css/charts.css" rel="stylesheet" type="text/css"/>\r\n\r\n<link type="image/png" href="https://www.vallibelfinance.com/site/images/favicon.png" rel="icon" />\r\n<!-- Global site tag (gtag.js) - Google Analytics -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-127381035-1"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n  gtag(\'config\', \'UA-127381035-1\');\r\n</script>\r\n\r\n<!-- Google tag (gtag.js) --> \r\n<script async src="https://www.googletagmanager.com/gtag/js?id=AW-11044036228"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'AW-11044036228\'); </script>\r\n\r\n<script src="https://www.vallibelfinance.com/site/js/jquery-2.2.0.min.js"></script>\r\n\r\n<script src="https://www.vallibelfinance.com/site/js/bootstrap.min.js"></script>\r\n\r\n<script src="https://www.vallibelfinance.com/site/js/custom.js"></script>\r\n<script src=\'https://www.google.com/recaptcha/api.js\'></script>\r\n \r\n<!-- search form validation-->\r\n <script type="text/javascript">\r\n     $(document).ready(function() {\r\n        $(\'form#searchform\').submit(function(e) {\r\n\t\t\te.preventDefault();\r\n   $(\'form#searchform .error\').remove();\r\n            var hasError = false;\r\n            $(\'.searchRequiredField\').each(function() {\r\n                if($.trim($(this).val()) == \'\') {\r\n                    var labelText = $(this).prev(\'label\').text();\r\n                    $(this).parent().append(\'<div class="error" style="text-align:right; color:red;">Required Field</div>\');\r\n                    $(this).addClass(\'inputError\');\r\n                    hasError = true;\r\n                } \r\n\t\t\t\t\r\n            });\r\n\r\n\r\n            if(!hasError) {\r\n\t\t\t\t\r\n                    $(\'#searchform\').off(\'submit\');\r\n\t\t\t\t\t\t$("#searchform").submit();\r\n\r\n\r\n            }\r\n            \r\n\r\n\r\n           return false;\r\n      });\r\n\t\t\r\n    });\r\n\r\n        </script>\r\n\r\n<!-- Facebook Pixel Code -->\r\n<script>\r\n!function(f,b,e,v,n,t,s)\r\n ...

# %%
import requests

# Making a GET request
r = requests.get('https://www.vallibelfinance.com/product/fixed-deposits')

# print request object
print(r.url)

# print status code
print(r.status_code)
# Out:
# https://www.vallibelfinance.com/product/fixed-deposits
# 200

# %%
from bs4 import BeautifulSoup

# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Vallibel Finance | Fixed Deposit Rates | Interest Rates
#   </title>
#   <meta content="Fixed Deposits | Fixed Deposit Rates | Interest Rates" name="keywords"/>
#   <meta content="Fixed Deposits. Your return on investment for the Fixed Deposits and capital is guaranteed. Attractive Fixed Deposit Rates. Pre-approved Loan against Fixed Deposit and interest charged only on amount used." name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="YzEcyiHgepNGneTmX9tjzt9xMSn9ZquejLOl7DNo" name="csrf-token">
#    <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR">
#     <meta content="telephone=no" name="format-detection">
#      <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#      <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#      <link href="https://fonts.googleapis.com/css?family=Roboto:100,300,400,500,700,900" rel="stylesheet"/>
#      <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,600,700,800" rel="stylesheet"/>
#      <link href="https://www.vallibelfinance.com/site/css/bootstrap.css" rel="stylesheet" type="text/css">
#       <link href="https://www.vallibelfinance.com/site/css/font-awesome.min.css" rel="stylesheet"/>
#       <link href="https://www.vallibelfinance.com/site/css/master.css" rel="stylesheet" type="text/css">
#        <link href="https://www.vallibelfinance.com/site/css/style.css" rel="stylesheet" type="text/css">
#         <link href="https://www.vallibelfinance.com/site/css/reset.css" rel="stylesheet" type="text/css"/>
#         <link href="https://www.vallibelfinance.com/site/css/charts.css" rel="stylesheet" type="text/css"/>
#         <link href="css/charts.css" rel="stylesheet" type="text/css"/>
#         <link href="https://www.vallibelfinance.com/site/images/favicon.png" rel="icon" type="image/png"/>
#         <!-- Global site tag (gtag.js) - Google Analytics -->
#         <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-127381035-1">
#         </script>
#         <script>
#          window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'UA-127381035-1');
#         </script>
#         <!-- Google tag (gtag.js) -->
#         <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-11044036228">
#         </script>
#         <script>
#          window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'AW-11044036228');
#         </script>
#         <script src="https://www.vallibelfinance.com/site/js/jquery-2.2.0.min.js">
#         </script>
#         <script src="https://www.vallibelfinance.com/site/js/bootstrap.min.js">
#         </script>
#         <script src="https://www.vallibelfinance.com/site/js/custom.js">
#         </script>
#         <script src="https://www.google.com/recaptcha/api.js">
#         </script>
#         <!-- search form validation-->
#         <script type="text/javascript">
#          $(document).ready(function() {
#         $('form#searchform').submit(function(e) {
# 			e.preventDefault();
#    $('form#searchform .error').remove();
#             var hasError = false;
#             $('.searchRequiredField').each(function() {
#                 if($.trim($(this).val()) == '') {
#                     var labelText = $(this).prev('label').text();
#                     $(this).parent().append('<div class="error" style="text-align:right; color:red;">Required Field</div>');
#                     $(this).addClass('inputError');
#                     hasError = true;
#                 }
#
#             });
#
#
#             if(!hasError) {
#
#                     $('#searchform').off('submit');
# 						$("#searchform").submit();
#
#
#             }
#
#
#
#            return false;
#       });
#
#     });
#         </script>
#         <!-- Facebook Pixel Code -->
#         <script>
#          !function(f,b,e,v,n,t,s)
# {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];
# s.parentNode.insertBefore(t,s)}(window,document,'script',
# 'https://connect.facebook.net/en_US/fbevents.js');
#  fbq('init', '304477344144055');
# fbq('track', 'PageView');
#         </script>
#         <noscript>
#          <img height="1" src="https://www.facebook.com/tr?id=304477344144055&amp;ev=PageView
# &amp;noscript=1" width="1"/>
#         </noscript>
#         <!-- End Facebook Pixel Code -->
#         <!-- Start Serviceform Insights Pixel -->
#         <script>
#          var tD=(new Date).toISOString().slice(0,10);window.sfpid = 301446;var u="https://serviceform.com/analytics/sf-pixel.js?"+tD,t=document.createElement("script");t.setAttribute("type","text/javascript"),t.setAttribute("src",u),t.async=!0,(document.getElementsByTagName("head")[0]||document.documentElement).appendChild(t);
#         </script>
#         <!-- End Serviceform Insights Pixel -->
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="row row_clr top_wrapper">
#    <div class="row row_clr top-ct">
#     <div class="col-xs-12 t-cont">
#      <ul class="list-inline">
#       <li>
#        <a href="tel:+94117480480">
#         <i aria-hidden="true" class="fa fa-phone tfa">
#         </i>
#         (+94) 11 7 480 480
#        </a>
#       </li>
#       <li>
#        <a href="mailto:info@vallibelfinance.com">
#         <i aria-hidden="true" class="fa fa-envelope tfa">
#         </i>
#         info@vallibelfinance.com
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="col-xs-12 t-soc">
#      <ul class="list-inline soc-list">
#       <li class="fb">
#        <a href="https://www.facebook.com/pg/VallibelFinancePLC/services/?ref=page_internal" target="_blank">
#         <i class="fa fa-facebook">
#         </i>
#        </a>
#       </li>
#       <li class="tw">
#        <a href="https://twitter.com/Vallibelfinance" target="_blank">
#         <i class="fa fa-twitter">
#         </i>
#        </a>
#       </li>
#       <li class="you">
#        <a href="https://www.instagram.com/vallibelfinance/?hl=en" target="_blank">
#         <i aria-hidden="true" class="fa fa-instagram">
#         </i>
#        </a>
#       </li>
#       <li class="you">
#        <a href="https://www.linkedin.com/company/vallibel-finance/" target="_blank">
#         <i aria-hidden="true" class="fa fa-linkedin">
#         </i>
#        </a>
#       </li>
#       <li class="you">
#        <a href="https://www.youtube.com/channel/UCzJGb71tl1qTuyr0oQUDkGw" target="_blank">
#         <i aria-hidden="true" class="fa fa-youtube-play">
#         </i>
#        </a>
#       </li>
#      </ul>
#      <ul class="list-inline lang-list">
#       <li>
#        <a class="la1" href="https://www.vallibelfinance.com/product/fixed-deposits">
#         <img alt="english" class="img-responsive" src="https://www.vallibelfinance.com/site/images/s1.jpg"/>
#        </a>
#       </li>
#       <li>
#        <a class="la2" href="https://www.vallibelfinance.com/si/product/fixed-deposits">
#         <img alt="sinhala" class="img-responsive" src="https://www.vallibelfinance.com/site/images/s2.jpg"/>
#        </a>
#       </li>
#       <li>
#        <a class="la3" href="https://www.vallibelfinance.com/ta/product/fixed-deposits">
#         <img alt="tamil" class="img-responsive" src="https://www.vallibelfinance.com/site/images/s3.jpg"/>
#        </a>
#       </li>
#      </ul>
#      <div class="col-xs-12 sdiv">
#       <div class="sb-search" id="sb-search">
#        <form action="https://www.vallibelfinance.com/search-me" id="searchform" method="post">
#         <input name="_token" type="hidden" value="YzEcyiHgepNGneTmX9tjzt9xMSn9ZquejLOl7DNo"/>
#         <input class="sb-search-input searchRequiredField" id="search" name="search" placeholder="Search Term..." type="search" value=""/>
#         <input class="sb-search-submit" type="submit" value=""/>
#         <span class="sb-icon-search">
#         </span>
#        </form>
#       </div>
#      </div>
#      <div class="sm-btn" id="sm-trigger">
#       <div class="line">
#       </div>
#       <div class="line">
#       </div>
#       <div class="line">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="navbar navbar-default center" id="navigation" role="navigation">
#     <div class="container-fluid">
#      <div class="navbar-header">
#       <button class="navbar-toggle collapsed" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a class="navbar-brand" href="https://www.vallibelfinance.com/index">
#        <img alt="logo" class="img-responsive" id="logo" src="https://www.vallibelfinance.com/site/images/logo.png"/>
#       </a>
#      </div>
#      <div class="navbar-collapse collapse">
#       <div class="navbar-inner">
#        <ul class="nav navbar-nav navbar-right" id="main-menu">
#         <li>
#          <a href="https://www.vallibelfinance.com/index">
#           Home
#          </a>
#         </li>
#         <li class="dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#           About Us
#          </a>
#          <ul class="dropdown-menu">
#           <li>
#            <a href="https://www.vallibelfinance.com/about">
#             The Company
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/board-of-directors">
#             Board of Directors
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/corporate-management-team">
#             Corporate Management Team
#            </a>
#           </li>
#           <!--<li><a href="#">Financial Highlights</a></li>-->
#           <li>
#            <a href="https://www.vallibelfinance.com/awards">
#             Awards
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/financial-highlights">
#             Financial Highlights
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#           Products &amp; Services
#          </a>
#          <ul class="dropdown-menu">
#           <li>
#            <a href="https://www.vallibelfinance.com/product/leasing">
#             Leasing
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/fixed-deposits">
#             Fixed Deposits
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/auto-draft">
#             Auto Draft
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/gold-loan">
#             Gold Loan
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/property-loans">
#             Property Loans
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/bonus-lease">
#             Bonus Lease
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/micro-leasing">
#             Micro Leasing
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/wheel-draft">
#             Wheel Draft
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/product/western-union">
#             Western Union
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#           Investor Relations
#          </a>
#          <ul class="dropdown-menu">
#           <li>
#            <a href="https://www.vallibelfinance.com/annual-report">
#             Annual Reports
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/quarterly-financial-statements">
#             Quarterly Financial Statements
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/corporate-information">
#             Corporate Information
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/branch">
#           Branches
#          </a>
#         </li>
#         <li class="dropdown">
#          <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#           Media
#          </a>
#          <ul class="dropdown-menu">
#           <!--<li><a href="annual-report.php">Annual Reports</a></li>
#
#
#
#                           <li><a href="quarterly-financial-statements.php">Interim Financial Statements</a></li>-->
#           <li>
#            <a href="https://www.vallibelfinance.com/news">
#             News &amp; Events
#            </a>
#           </li>
#           <li>
#            <a href="https://www.vallibelfinance.com/corporate-video">
#             Corporate Video
#            </a>
#           </li>
#          </ul>
#         </li>
#         <!--<li class="dropdown">
#
#
#
#                       <a href="download.php" class="dropdown-toggle" data-toggle="dropdown" role="button" aria-haspopup="true" aria-expanded="false">Downloads</a>
#
#
#
#                       <ul class="dropdown-menu">
#
#
#
#                           <li><a href="#">Forms</a></li>
#
#
#
#                           <li><a href="#">Applications</a></li>
#
#
#
#                       </ul>
#
#
#
#                   </li>-->
#         <li>
#          <a href="https://www.vallibelfinance.com/download">
#           Downloads
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/contact-us">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <!--/.nav-collapse -->
#     </div>
#    </div>
#   </div>
#   <!--end top_wrapper-->
#   <div class="col-xs-12">
#   </div>
#   <div class="row row_clr sitemap-div">
#    <div id="close-btn">
#     X
#    </div>
#    <h1>
#     Vallibel Finance
#    </h1>
#    <h3>
#     Sitemap
#    </h3>
#    div class="row"&gt;
#    <div class="site-map">
#     <div class="site-map-menu">
#      <div class="col-xs-12">
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/index">
#          Home
#         </a>
#        </h4>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/about">
#          About Us
#         </a>
#        </h4>
#        <ul class="map-sub-1">
#         <li>
#          <a href="https://www.vallibelfinance.com/about">
#           The Company
#          </a>
#          <ul class="map-sub-1-sub2">
#           <!-- <li><a href="https://www.vallibelfinance.com/about#vision">Vision, Mission &amp; Values</a></li>
#
#
#
#                                 <li>Key Milestones</li>-->
#          </ul>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/board-of-directors">
#           Board of Directors
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/corporate-management-team">
#           Senior Management
#          </a>
#         </li>
#         <!--<li><a href="#">Financial Highlights</a></li>-->
#         <li>
#          <a href="https://www.vallibelfinance.com/awards">
#           Awards
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/financial-highlights">
#           Financial Highlights
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="#">
#          Products &amp; Services
#         </a>
#        </h4>
#        <ul class="map-sub-1">
#         <li>
#          <a href="https://www.vallibelfinance.com/product/leasing">
#           Leasing
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/fixed-deposits">
#           Fixed Deposits
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/auto-draft">
#           Auto Draft
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/gold-loan">
#           Gold Loan
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/property-loans">
#           Property Loans
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/bonus-lease">
#           Bonus Lease
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/micro-leasing">
#           Micro Leasing
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/wheel-draft">
#           Wheel Draft
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/product/western-union">
#           Western Union
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="#">
#          Investor Relations
#         </a>
#        </h4>
#        <ul class="map-sub-1">
#         <li>
#          <a href="https://www.vallibelfinance.com/annual-report">
#           Annual Reports
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/quarterly-financial-statements">
#           Quarterly Financial Statements
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/corporate-information">
#           Corporate Information
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-xs-12">
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/branch">
#          Branch Network
#         </a>
#        </h4>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/download">
#          Downloads
#         </a>
#        </h4>
#        <ul class="map-sub-1">
#         <!-- <li><a href="#">Brochures</a> </li>-->
#         <li>
#          <a href="https://www.vallibelfinance.com/download#form">
#           Forms
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/download#application">
#           Applications
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="#">
#          Media
#         </a>
#        </h4>
#        <ul class="map-sub-1">
#         <!-- <li><a href="#">Videos</a></li>
#
#
#
#                             <li><a href="#">Promotions</a></li>-->
#         <li>
#          <a href="https://www.vallibelfinance.com/news">
#           News &amp; Events
#          </a>
#         </li>
#         <li>
#          <a href="https://www.vallibelfinance.com/corporate-video">
#           Corporate Video
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/careers">
#          Careers
#         </a>
#        </h4>
#       </div>
#      </div>
#      <div class="col-xs-12">
#       <div class="col-xs-3">
#        <h4>
#         <a href="#">
#          FAQ
#         </a>
#        </h4>
#       </div>
#       <div class="col-xs-3">
#        <h4>
#         <a href="https://www.vallibelfinance.com/contact-us">
#          Contact Us
#         </a>
#        </h4>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="carousel slide carousel-fade about-slider" data-ride="carousel" id="home-slider">
#    <!-- Wrapper for slides -->
#    <div class="carousel-inner">
#     <div class="item active">
#      <img alt="Fixed Deposits | Fixed Deposit Rates" class="hidden-xs" src="https://www.vallibelfinance.com/uploads/products/6651611124345FD-Wide.jpg"/>
#      <img alt="Fixed Deposits | Fixed Deposit Rates" class="visible-xs" src="https://www.vallibelfinance.com/uploads/products/7291611124345FD-Wide-S.jpg"/>
#     </div>
#    </div>
#   </div>
#   <div class="row row_clr about-middle product-middle content">
#    <div class="container">
#     <div class="col-xs-12">
#      <h1 class="main-head">
#       <span>
#        Fixed
#       </span>
#       Deposits
#      </h1>
#     </div>
#     <div class="col-xs-12 no-pad">
#      <div class="col-sm-6 col-xs-12 product-left">
#       <p>
#        For almost a decade, Vallibel Finance has been regarded with a high level of trust and confidence, as is evident in the year-on-year growth of our fixed deposits portfolio.
#       </p>
#       <p>
#        Providing you with the highest level of security for your fixed deposits, we guarantee the safe return of your fixed deposits. Furthermore, we strive to offer you the best fixed deposit options, in compliance with the regulations of the Central Bank of Sri Lanka, with attractive fixed deposit rates and a high return on investment.
#       </p>
#       <h4 style="color: #ed2024; font-size: 20px; font-weight: 900; margin: 5px 0 25px;">
#        Reasons to select our Fixed Deposits
#       </h4>
#       <ul class="list-unstyled">
#        <li class="fea-li">
#         Your return on investment for the Fixed Deposits and capital is guaranteed
#        </li>
#        <li class="fea-li">
#         Attractive Fixed Deposit Rates
#        </li>
#        <li class="fea-li">
#         Pre-approved loan against Fixed Deposit and interest charged only on amount used
#        </li>
#        <li class="fea-li">
#         Superior customer service
#        </li>
#        <li class="fea-li">
#         Free investment advisory services
#        </li>
#       </ul>
#      </div>
#      <div class="col-sm-6 col-xs-12 product-right">
#       <div class="rg-container">
#        <div class="header">
#         <h3>
#          Normal Citizen
#         </h3>
#        </div>
#        <table class="rg-table" summary="Hed">
#         <thead>
#          <tr>
#           <th class="text">
#            Period
#           </th>
#           <th class="text">
#            Monthly
#           </th>
#           <th class="text">
#            A.E.R
#           </th>
#           <th class="text">
#            Maturity
#           </th>
#           <th class="text">
#            A.E.R
#           </th>
#          </tr>
#         </thead>
#         <tbody>
#          <tr class="">
#           <td class="text" data-title="Period">
#            1 Month
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            2 Month
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.28%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            3 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#           <td class="text" data-title="Maturity">
#            15.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            15.87%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            4 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            12.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.49%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            6 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            13.75%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.65%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            15.03%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            1 Year
#           </td>
#           <td class="text" data-title="Monthly">
#            12.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.68%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.00%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            18 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            12.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.68%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.61%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            2 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            12.25%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.96%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.25%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.47%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            3 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            13.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.80%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.40%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            4 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            13.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.80%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            11.76%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            5 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            12.75%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.52%
#           </td>
#           <td class="text" data-title="Maturity">
#            15.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            11.84%
#           </td>
#          </tr>
#         </tbody>
#        </table>
#       </div>
#       <div class="rg-container">
#        <div class="header">
#         <h3>
#          Senior Citizen
#         </h3>
#        </div>
#        <table class="rg-table" summary="Hed">
#         <thead>
#          <tr>
#           <th class="text">
#            Period
#           </th>
#           <th class="text">
#            Monthly
#           </th>
#           <th class="text">
#            A.E.R
#           </th>
#           <th class="text">
#            Maturity
#           </th>
#           <th class="text">
#            A.E.R
#           </th>
#          </tr>
#         </thead>
#         <tbody>
#          <tr class="">
#           <td class="text" data-title="Period">
#            1 Month
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            2 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.28%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            3 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#           <td class="text" data-title="Maturity">
#            15.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            15.87%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            4 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            -
#           </td>
#           <td class="text" data-title="A.E.R">
#            -
#           </td>
#           <td class="text" data-title="Maturity">
#            12.00%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.49%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            6 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            13.75%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.65%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            15.03%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            1 Year
#           </td>
#           <td class="text" data-title="Monthly">
#            12.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.24%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.50%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            18 Months
#           </td>
#           <td class="text" data-title="Monthly">
#            12.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.24%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.08%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            2 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            12.75%
#           </td>
#           <td class="text" data-title="A.E.R">
#            13.52%
#           </td>
#           <td class="text" data-title="Maturity">
#            13.75%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.92%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            3 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.79%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            4 Years
#           </td>
#           <td class="text" data-title="Monthly">
#            13.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.37%
#           </td>
#           <td class="text" data-title="Maturity">
#            14.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.12%
#           </td>
#          </tr>
#          <tr class="">
#           <td class="text" data-title="Period">
#            5 years
#           </td>
#           <td class="text" data-title="Monthly">
#            13.25%
#           </td>
#           <td class="text" data-title="A.E.R">
#            14.09%
#           </td>
#           <td class="text" data-title="Maturity">
#            15.50%
#           </td>
#           <td class="text" data-title="A.E.R">
#            12.16%
#           </td>
#          </tr>
#         </tbody>
#        </table>
#        <p class="condition">
#         <span style="color: #ff0000;">
#          * The above Fixed Deposit Rates are indicative and subject to change based on the Central Bank Directions.
#         </span>
#        </p>
#       </div>
#       <h3 style="color: #000; font-size: 20px;">
#        <strong>
#         Call us for more details on Fixed Deposits
#         <br/>
#        </strong>
#       </h3>
#       <p class="tel">
#        <i class="fa fa-phone">
#        </i>
#        <a href="tel:(0094)114393133">
#         (+94) 11 4 393 133
#        </a>
#        <span>
#         |
#        </span>
#        <a href="tel:(0094)719449449">
#         (+94) 71 9 449 449
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   ﻿
#   <div class="row row_clr incorporation">
#    <div class="container">
#     <div class="col-xs-12 inc-in">
#      <div class="col-xs-12 no-pad">
#       <ul class="list-inline">
#        <li>
#         <a href="https://www.vallibelfinance.com/careers">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          FAQ's
#         </a>
#        </li>
#        <li>
#         <a href="https://www.vallibelfinance.com/customer-protection">
#          Customer Protection
#         </a>
#        </li>
#        <li>
#         <a href="https://www.vallibelfinance.com/financial-information">
#          Financial Information &amp; KPIs
#         </a>
#        </li>
#        <li>
#         <a href="https://www.vallibelfinance.com/credit-report">
#          Credit Rating Reports
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          Terms &amp; Conditions
#         </a>
#        </li>
#       </ul>
#      </div>
#      <p>
#       <b>
#        Date of incorporation:
#       </b>
#       5th September 1974 Licensed by the Monetary Board of the Central Bank of Sri Lanka under the Finance Business Act No. 42 of 2011 |
#       <br/>
#       <strong>
#        Credit Rating :
#       </strong>
#       BBB+ Stable Outlook Moody's ICRA |
#       <strong>
#        Company Reg.No
#       </strong>
#       : PB 526/PQ
#      </p>
#      <!--<p>Credit Rating BBB Stable rating  by  ICRA Privacy Policy | Vallibel Finance PLC | © Copyright 2018 All rights reserved.</p>-->
#     </div>
#    </div>
#   </div>
#   <div class="row row_clr fotter">
#    <div class="col-xs-12">
#     <p class="company">
#      ©
#      <span id="year">
#      </span>
#      for Vallibel Finance by:
#      <a href="http://www.230i.com" target="_blank">
#       230 interactive
#      </a>
#     </p>
#    </div>
#   </div>
#   <script src="https://www.vallibelfinance.com/site/js/classie.js">
#   </script>
#   <script src="https://www.vallibelfinance.com/site/js/uisearch.js">
#   </script>
#   <!--Snow Effect-->
#   <!--
# <script src="https://www.vallibelfinance.com/site/js/snowfall.jquery.min.js"></script>
# <script>
#  $(window).on('load', function() {
#      $(document).snowfall({round : true, flakeCount :100, minSize: 5, maxSize: 12, deviceorientation : true});
#   });
# </script>
# -->
#   <!--Snow Effect-->
#   <script>
#    new UISearch( document.getElementById( 'sb-search' ) );
#
#
#
#
#
#
#
# $( ".home-middle .tab-content .tab-in" ).hover(function() {
#
#
#
#     var did = $(this).data('id');
#
#
#
#     did = ("#"+did);
#
#
#
#     $(did).addClass('hvrd');
#
#
#
#   }, function() {
#
#
#
#     var did = $(this).data('id');
#
#
#
#     did = ("#"+did);
#
#
#
#    $(did).removeClass('hvrd');
#
#
#
#   }
#
#
#
# );
#
#
#
#
#
#
#
# $("#sm-trigger").click(function() {
#
#
#
#
#
#   $('.sitemap-div').toggleClass('act')
#
#
#
# });
#
#
#
#
#
#
#
# $("#close-btn").click(function() {
#
#
#
#   $('.sitemap-div').removeClass('act')
#
#
#
# });
#
#
#
#
#
#
#
#   $(function(){
#
#
#
#     $('.top_wrapper').affix({
#
#
#
#       offset: {
#
#
#
#         /* Affix the navbar after scroll below header */
#
#
#
#         top: $("#home-slider").outerHeight(true) - 0}
#
#
#
#     });
#
#
#
# });
#   </script>
#   <!--
#
#
#
# <div id="tp">
#
#
#
# <a href="#top">
#
#
#
# <div class="top-button" id="tp-button">
#
#
#
# <i class="fa fa-chevron-up"></i>
#
#
#
# </div>
#
#
#
# </a>
#
#
#
# </div>
#
#
#
#
#
#
#
# <div id="mtp">
#
#
#
# <a href="#mob">
#
#
#
# <div class="top-button" id="tp-button2">
#
#
#
# <i class="fa fa-chevron-up"></i>
#
#
#
# </div>
#
#
#
# </a></div>
#
#
#
#
#
#
#
# <script src="js/jquery.waypoints.min.js"></script>
#
#
#
# -->
#   <script>
#    $( document ).ready(function() {
#
#
#
#     var d = new Date();
#
#
#
#     var n = d.getFullYear();
#
#
#
#     document.getElementById("year").innerHTML = n;
#
#
#
# });
#   </script>
#   <script type="text/javascript">
#    var url = window.location;
#
#
#
#     // Will only work if string in href matches with location
#
#
#
#     $('ul.nav a[href="'+ url +'"]').parent().addClass('active');
#
#
#
#     $('ul.nav li ul.dropdown-menu li a[href="'+ url +'"]').parent().parent().parent().addClass('active');
#
#
#
#
#
#
#
#     // Will also work for relative and absolute hrefs
#
#
#
#     $('ul.nav a').filter(function() {
#
#
#
#         return this.href == url;
#
#
#
#     }).parent().addClass('active');
#
#
#
#     $('ul.nav li ul.dropdown-menu li a').filter(function() {
#
#
#
#         return this.href == url;
#
#
#
#     }).parent().parent().parent().addClass('active');
#   </script>
#  </body>
# </html>

# %%
# Getting the title tag
print(soup.title)

# Getting the name of the tag
print(soup.title.name)

# Getting the name of parent tag
print(soup.title.parent.name)

# use the child attribute to get
# the name of the child tag
# Out:
# <title>Vallibel Finance | Fixed Deposit Rates | Interest Rates</title>
# title
# head

# %%
#extract all the links
# find all the anchor tags with "href"
for link in soup.find_all('a'):
	print(link.get('href'))
# Out:
# None
# /
# #page-top
# /
# /cloud-scraper
# /pricing
# #section3
# /documentation
# /tutorials
# /how-to-videos
# /test-sites
# https://forum.webscraper.io/
# https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en
# https://cloud.webscraper.io/
# /test-sites/e-commerce/allinone
# /test-sites/e-commerce/allinone/phones
# /test-sites/e-commerce/allinone/computers
# /test-sites/e-commerce/allinone/computers/tablets
# /test-sites/e-commerce/allinone/computers/laptops
# /test-sites/e-commerce/allinone/product/545
# /test-sites/e-commerce/allinone/product/546
# /test-sites/e-commerce/allinone/product/547
# /test-sites/e-commerce/allinone/product/517
# /test-sites/e-commerce/allinone/product/548
# /test-sites/e-commerce/allinone/product/549
# /test-sites/e-commerce/allinone/product/550
# /test-sites/e-commerce/allinone/product/551
# /test-sites/e-commerce/allinone/product/552
# /test-sites/e-commerce/allinone/product/553
# /test-sites/e-commerce/allinone/product/554
# /test-sites/e-commerce/allinone/product/555
# /test-sites/e-commerce/allinone/product/530
# /test-sites/e-commerce/allinone/product/556
# /test-sites/e-commerce/allinone/product/557
# /test-sites/e-commerce/allinone/product/558
# /test-sites/e-commerce/allinone/product/559
# /test-sites/e-commerce/allinone/product/560
# /test-sites/e-commerce/allinone/product/561
# /test-sites/e-commerce/allinone/product/516
# /test-sites/e-commerce/allinone/product/562
# /test-sites/e-commerce/allinone/product/563
# /test-sites/e-commerce/allinone/product/564
# /test-sites/e-commerce/allinone/product/565
# /test-sites/e-commerce/allinone/product/566
# /test-sites/e-commerce/allinone/product/567
# /test-sites/e-commerce/allinone/product/568
# /test-sites/e-commerce/allinone/product/569
# /test-sites/e-commerce/allinone/product/570
# /test-sites/e-commerce/allinone/product/571
# /test-sites/e-commerce/allinone/product/572
# /test-sites/e-commerce/allinone/product/573
# /test-sites/e-commerce/allinone/product/574
# /test-sites/e-commerce/allinone/product/575
# /test-sites/e-commerce/allinone/product/531
# /test-sites/e-commerce/allinone/product/576
# /test-sites/e-commerce/allinone/product/577
# /test-sites/e-commerce/allinone/product/578
# /test-sites/e-commerce/allinone/product/527
# /test-sites/e-commerce/allinone/product/532
# /test-sites/e-commerce/allinone/product/529
# /test-sites/e-commerce/allinone/product/521
# /test-sites/e-commerce/allinone/product/523
# /test-sites/e-commerce/allinone/product/533
# /test-sites/e-commerce/allinone/product/534
# /test-sites/e-commerce/allinone/product/535
# /test-sites/e-commerce/allinone/product/519
# /test-sites/e-commerce/allinone/product/524
# /test-sites/e-commerce/allinone/product/536
# /test-sites/e-commerce/allinone/product/537
# /test-sites/e-commerce/allinone/product/538
# /test-sites/e-commerce/allinone/product/539
# /test-sites/e-commerce/allinone/product/522
# /test-sites/e-commerce/allinone/product/579
# /test-sites/e-commerce/allinone/product/580
# /test-sites/e-commerce/allinone/product/581
# /test-sites/e-commerce/allinone/product/582
# /test-sites/e-commerce/allinone/product/583
# /test-sites/e-commerce/allinone/product/584
# /test-sites/e-commerce/allinone/product/585
# /test-sites/e-commerce/allinone/product/586
# /test-sites/e-commerce/allinone/product/587
# /test-sites/e-commerce/allinone/product/588
# /test-sites/e-commerce/allinone/product/589
# /test-sites/e-commerce/allinone/product/590
# /test-sites/e-commerce/allinone/product/591
# /test-sites/e-commerce/allinone/product/592
# /test-sites/e-commerce/allinone/product/593
# /test-sites/e-commerce/allinone/product/594
# /test-sites/e-commerce/allinone/product/595
# /test-sites/e-commerce/allinone/product/596
# /test-sites/e-commerce/allinone/product/597
# /test-sites/e-commerce/allinone/product/540
# /test-sites/e-commerce/allinone/product/598
# /test-sites/e-commerce/allinone/product/599
# /test-sites/e-commerce/allinone/product/600
# /test-sites/e-commerce/allinone/product/601
# /test-sites/e-commerce/allinone/product/602
# /test-sites/e-commerce/allinone/product/518
# /test-sites/e-commerce/allinone/product/603
# /test-sites/e-commerce/allinone/product/604
# /test-sites/e-commerce/allinone/product/605
# /test-sites/e-commerce/allinone/product/606
# /test-sites/e-commerce/allinone/product/607
# /test-sites/e-commerce/allinone/product/608
# /test-sites/e-commerce/allinone/product/609
# /test-sites/e-commerce/allinone/product/610
# /test-sites/e-commerce/allinone/product/611
# /test-sites/e-commerce/allinone/product/528
# /test-sites/e-commerce/allinone/product/612
# /test-sites/e-commerce/allinone/product/613
# /test-sites/e-commerce/allinone/product/614
# /test-sites/e-commerce/allinone/product/526
# /test-sites/e-commerce/allinone/product/615
# /test-sites/e-commerce/allinone/product/616
# /test-sites/e-commerce/allinone/product/617
# /test-sites/e-commerce/allinone/product/618
# /test-sites/e-commerce/allinone/product/525
# /test-sites/e-commerce/allinone/product/619
# /test-sites/e-commerce/allinone/product/620
# /test-sites/e-commerce/allinone/product/621
# /test-sites/e-commerce/allinone/product/520
# /test-sites/e-commerce/allinone/product/622
# /test-sites/e-commerce/allinone/product/623
# /test-sites/e-commerce/allinone/product/624
# /test-sites/e-commerce/allinone/product/625
# /test-sites/e-commerce/allinone/product/626
# /test-sites/e-commerce/allinone/product/627
# /test-sites/e-commerce/allinone/product/628
# /test-sites/e-commerce/allinone/product/629
# /test-sites/e-commerce/allinone/product/630
# /test-sites/e-commerce/allinone/product/631
# /test-sites/e-commerce/allinone/product/541
# /test-sites/e-commerce/allinone/product/632
# /test-sites/e-commerce/allinone/product/542
# /test-sites/e-commerce/allinone/product/543
# /test-sites/e-commerce/allinone/product/544
# /
# /pricing
# /about-us
# /contact
# /privacy-policy
# /extension-privacy-policy
# https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip
# /jobs
# /blog
# /documentation
# /tutorials
# /screenshots
# /test-sites
# https://forum.webscraper.io/
# https://status.webscraper.io/
# mailto:info@webscraper.io
# https://www.facebook.com/webscraperio/
# https://twitter.com/webscraperio
# #

# %%
images_list = []

images = soup.select('img')
for image in images:
	src = image.get('src')
	alt = image.get('alt')
	images_list.append({"src": src, "alt": alt})

for image in images_list:
	print(image)
# Out:
# {'src': 'https://www.facebook.com/tr?id=304477344144055&ev=PageView\r\n&noscript=1', 'alt': None}
# {'src': 'https://www.vallibelfinance.com/site/images/s1.jpg', 'alt': 'english'}
# {'src': 'https://www.vallibelfinance.com/site/images/s2.jpg', 'alt': 'sinhala'}
# {'src': 'https://www.vallibelfinance.com/site/images/s3.jpg', 'alt': 'tamil'}
# {'src': 'https://www.vallibelfinance.com/site/images/logo.png', 'alt': 'logo'}
# {'src': 'https://www.vallibelfinance.com/uploads/products/6651611124345FD-Wide.jpg', 'alt': 'Fixed Deposits | Fixed Deposit Rates'}
# {'src': 'https://www.vallibelfinance.com/uploads/products/7291611124345FD-Wide-S.jpg', 'alt': 'Fixed Deposits | Fixed Deposit Rates'}

# %%
import requests
from bs4 import BeautifulSoup as bs
import csv

URL = 'https://www.geeksforgeeks.org/page/'

# Make an HTTP GET request to the URL
req = requests.get(URL)

# Check if the request was successful before proceeding
if req.status_code == 200:
    soup = bs(req.text, 'html.parser')

    titles = soup.find_all('div', attrs={'class': 'head'})
    titles_list = []

    count = 1
    for title in titles:
        d = {}
        d['Title Number'] = f'Title {count}'
        d['Title Name'] = title.text.strip()  # Use strip() to remove extra whitespace
        count += 1
        titles_list.append(d)

    filename = 'titles.csv'
    with open(filename, 'w', newline='') as f:
        w = csv.DictWriter(f, ['Title Number', 'Title Name'])
        w.writeheader()
        w.writerows(titles_list)

# %% [markdown]
# #Basics in web scraping

# %%
# Import library
from bs4 import BeautifulSoup
import requests

# %%
# Define URL
url = 'https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops'
# Ask hosting server to fetch url
requests.get(url)
# Out:
# <Response [200]>

# %%
pages = requests.get(url)
pages.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<!-- Google Tag Manager -->\n<script>(function (w, d, s, l, i) {\n\t\tw[l] = w[l] || [];\n\t\tw[l].push({\n\t\t\t\'gtm.start\':\n\t\t\t\tnew Date().getTime(), event: \'gtm.js\'\n\t\t});\n\t\tvar f = d.getElementsByTagName(s)[0],\n\t\t\tj = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n\t\tj.async = true;\n\t\tj.src =\n\t\t\t\'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n\t\tf.parentNode.insertBefore(j, f);\n\t})(window, document, \'script\', \'dataLayer\', \'GTM-NVFPDWB\');</script>\n<!-- End Google Tag Manager -->\n\t<title>Web Scraper Test Sites</title>\n\t<meta charset="utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n\n\t<meta name="keywords"\n\t\t  content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper"/>\n\t<meta name="description"\n\t\t  content="The most popular web scraping extension. Start scraping in minutes. Automate your tasks with our Cloud Scraper. No software to download, no coding needed."/>\n\t<link rel="icon" sizes="128x128" href="/favicon.png">\n\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\t\n\t<link rel="stylesheet" href="/css/app.css?id=b7f9a4db575e926ab19a7a22ea90b619">\n\t<link rel="stylesheet" href="/css/ws-icons.css?id=1b22281f009b15cf292197a5ccf42e3f">\n\n\t<link rel="canonical" href="https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops">\n\t<link rel="apple-touch-icon" href="/img/logo-icon.png">\n\n\t\t<script defer src="/js/app.js?id=429f2709822cf43829f5cc86ae4e17f4"></script>\n\n\t\n</head>\n<body>\n<!-- Google Tag Manager (noscript) -->\n<noscript>\n\t<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB"\n\t        height="0" width="0" style="display:none;visibility:hidden"></iframe>\n</noscript>\n<!-- End Google Tag Manager (noscript) -->\n<header role="banner" class="navbar navbar-fixed-top navbar-static">\n\t<div class="container">\n\n\t\t<div class="navbar-header">\n\n\t\t\t<a data-toggle="collapse-side" data-target=".side-collapse" data-target-2=".side-collapse-container">\n\t\t\t\t<button type="button" class="navbar-toggle pull-right collapsed" data-toggle="collapse"\n\t\t\t\t\t\tdata-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse"\n\t\t\t\t\t\taria-expanded="false" aria-controls="navbar">\n\n\t\t\t\t\t<span class="sr-only">Toggle navigation</span>\n\t\t\t\t\t<span class="icon-bar top-bar"></span>\n\t\t\t\t\t<span class="icon-bar middle-bar"></span>\n\t\t\t\t\t<span class="icon-bar bottom-bar"></span>\n\n\t\t\t\t</button>\n\t\t\t</a>\n\t\t\t<div class="navbar-brand">\n\t\t\t\t<a href="/"><img src="/img/logo_white.svg" alt="Web Scraper"></a>\n\t\t\t</div>\n\t\t</div>\n\n\t\t<div class="side-collapse in">\n\t\t\t<nav id="navbar" role="navigation" class="navbar-collapse collapse">\n\t\t\t\t<ul class="nav navbar-nav navbar-right">\n\t\t\t\t\t<li class="hidden">\n\t\t\t\t\t\t<a href="#page-top"></a>\n\t\t\t\t\t</li>\n\t\t\t\t\t<li>\n\t\t\t\t\t\t<a href="/" class="menuitm">\n\t\t\t\t\t\t\t<p>Web Scraper</p>\n\t\t\t\t\t\t\t<div class="crta"></div>\n\t\t\t\t\t\t</a>\n\t\t\t\t\t</li>\n\t\t\t\t\t<li>\n\t\t\t\t\t\t<a href="/cloud-scraper" class="menuitm">\n\t\t\t\t\t\t\t<p>Cloud Scraper</p>\n\t\t\t\t\t\t\t<div class="crta"></div>\n\t\t\t\t\t\t</a>\n\t\t\t\t\t</li>\n\t\t\t\t\t<li>\n\t\t\t\t\t\t<a href="/pricing" class="menuitm">\n\t\t\t\t\t\t\t<p>Pricing</p>\n\t\t\t\t\t\t\t<div class="crta"></div>\n\t\t\t\t\t\t</a>\n\t\t\t\t\t</li>\n\t\t\t\t\t<li class="dropdown">\n\t\t\t\t\t\t<a href="#section3" class="menuitm dropdown-toggle" data-toggle="dropdown">\n\t\t\t\t\t\t\t<p>Learn</p>\n\t\t\t\t\t\t\t<div class="crta"></div>\n\t\t\t\t\t\t</a>\n\t\t\t\t\t\t<ul class="dropdown-menu">\n\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t<a href="/documentation">Documentation</a>\n\t\t\t\t\t\t\t</li>\n\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t<a href="/tutorials">Video Tutorials</a>\n\t\t\t\t\t\t\t< ...

# %%
# parser-lxml = Change html to Python friendly format
soup = BeautifulSoup(pages.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# <meta content="The most popular web scraping extension. Start scraping in minutes. Automate your tasks with our Cloud Scraper. No software to download, no coding needed." name="description"/>
# <link href="/favicon.png" rel="icon" sizes="128x128"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/css/app.css?id=b7f9a4db575e926ab19a7a22ea90b619" rel="stylesheet"/>
# <link href="/css/ws-icons.css?id=1b22281f009b15cf292197a5ccf42e3f" rel="stylesheet"/>
# <link href="https://webscraper.io/test-sites/e-commerce/allinone/computers/laptops" rel="canonical"/>
# <link href="/img/logo-icon.png" rel="apple-touch-icon"/>
# <script defer="" src="/js/app.js?id=429f2709822cf43829f5cc86ae4e17f4"></script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NVFPDWB" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <header class="navbar navbar-fixed-top navbar-static" role="banner">
# <div class="container">
# <div class="navbar-header">
# <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="hidden">
# <a href="#page-top"></a>
# </li>
# <li>
# <a class="menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li>
# <a class="menuitm" href="/cloud-scraper">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li>
# <a class="menuitm" href="/pricing">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="dropdown">
# <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
# <p>Learn</p>
# <div class="crta"></div>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/how-to-videos">How to</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
# </li>
# <li>
# <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </header>
# <div class="wrapper">
# <div class="formenu-here container-fluid">
# </div>
# <div class="container-fluid blog-hero">
# <div class="container">
# <div class="row">
# <div class="col-md-12">
# <h1>Test Sites</h1>
# </div>
# </div>
# </div>
# </div>
# <div class="container test-site">
# <div class="row">
# <div class="col-md-3 sidebar">
# <div class="navbar-default sidebar" role="navigation">
# <div class="sidebar-nav navbar-collapse">
# <ul class="nav" id="side-menu">
# <li>
# <a href="/test-sites/e-commerce/allinone">Home</a>
# </li>
# <li>
# <a class="category-link" href="/test-sites/e-commerce/allinone/phones">
# 					Phones
# 					<span class="fa arrow"></span>
# </a>
# </li>
# <li class="active">
# <a class="category-link" href="/test-sites/e-commerce/allinone/computers">
# 					Computers
# 					<span class="fa arrow"></span>
# </a>
# <ul class="nav nav-second-level collapse in">
# <li>
# <a class="subcategory-link" href="/test-sites/e-commerce/allinone/computers/tablets">
# 							Tablets
# 						</a>
# </li>
# <li>
# <a class="subcategory-link active" href="/test-sites/e-commerce/allinone/computers/laptops">
# 							Laptops
# 						</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-md-9">
# <h1 class="page-header">Computers / Laptops</h1>
# <div class="row">
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$295.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/545" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4...</a>
# </h4>
# <p class="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">14 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$299.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/546" title="Prestigio SmartBook 133S Dark Grey">Prestigio SmartB...</a>
# </h4>
# <p class="description">Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$299.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/547" title="Prestigio SmartBook 133S Gold">Prestigio SmartB...</a>
# </h4>
# <p class="description">Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$306.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/517" title="Aspire E1-510">Aspire E1-510</a>
# </h4>
# <p class="description">15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$321.94</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/548" title="Lenovo V110-15IAP">Lenovo V110-15IA...</a>
# </h4>
# <p class="description">Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">5 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$356.49</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/549" title="Lenovo V110-15IAP">Lenovo V110-15IA...</a>
# </h4>
# <p class="description">Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">6 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$364.46</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/550" title="Hewlett Packard 250 G6 Dark Ash Silver">Hewlett Packard...</a>
# </h4>
# <p class="description">Hewlett Packard 250 G6 Dark Ash Silver, 15.6" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$372.70</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/551" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$379.94</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/552" title="Acer Aspire A315-31-C33J">Acer Aspire A315...</a>
# </h4>
# <p class="description">Acer Aspire A315-31-C33J Black 15.6", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG</p>
# </div>
# <div class="ratings">
# <p class="pull-right">0 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$379.95</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/553" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$391.48</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/554" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">10 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$393.88</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/555" title="Acer Aspire 3 A315-21">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-21, 15.6", AMD A4-9120. 4GB. 128GB SSD, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$399.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/530" title="Asus VivoBook Max">Asus VivoBook Ma...</a>
# </h4>
# <p class="description">Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$399.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/556" title="Asus VivoBook E502NA-GO022T Dark Blue">Asus VivoBook E5...</a>
# </h4>
# <p class="description">Asus VivoBook E502NA-GO022T Dark Blue, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">3 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$404.23</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/557" title="Lenovo ThinkPad E31-80">Lenovo ThinkPad...</a>
# </h4>
# <p class="description">Lenovo ThinkPad E31-80, 13.3" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$408.98</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/558" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">10 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$409.63</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/559" title="Lenovo V110-15ISK">Lenovo V110-15IS...</a>
# </h4>
# <p class="description">Lenovo V110-15ISK, 15.6" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$410.46</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/560" title="Acer Aspire ES1-732 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-732 Black, 17.3" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">14 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$410.66</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/561" title="Asus VivoBook 15 X540NA-GQ026T">Asus VivoBook 15...</a>
# </h4>
# <p class="description">Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$416.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/516" title="Packard 255 G2">Packard 255 G2</a>
# </h4>
# <p class="description">15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$433.30</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/562" title="Asus EeeBook R416NA-FA014T">Asus EeeBook R41...</a>
# </h4>
# <p class="description">Asus EeeBook R416NA-FA014T, 14" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$436.29</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/563" title="Acer Aspire 3 A315-51">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-51, 15.6" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$436.29</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/564" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$439.73</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/565" title="Acer Extensa 15 (2540) Black">Acer Extensa 15...</a>
# </h4>
# <p class="description">Acer Extensa 15 (2540) Black, 15.6" HD, Core i5-7200U, 4GB, 500GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">6 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$454.62</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/566" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i5-7200U, 4GB, 500GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$454.73</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/567" title="Lenovo V110-15ISK">Lenovo V110-15IS...</a>
# </h4>
# <p class="description">Lenovo V110-15ISK, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$457.38</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/568" title="Acer Aspire A315-51-33TG">Acer Aspire A315...</a>
# </h4>
# <p class="description">Acer Aspire A315-51-33TG, Black 15.6" HD, Core i3-7100U, 4GB DDR4, 128GB SSD, Windows 10 Home, ENG</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$465.95</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/569" title="Lenovo V110-15IKB">Lenovo V110-15IK...</a>
# </h4>
# <p class="description">Lenovo V110-15IKB, 15.6" HD, Core i5-7200U, 4GB, 500GB, DOS</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$468.56</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/570" title="Asus VivoBook 15 X540UA-DM260 Chocolate Black">Asus VivoBook 15...</a>
# </h4>
# <p class="description">Asus VivoBook 15 X540UA-DM260 Chocolate Black, 15.6" FHD, Core i3-6006U, 4GB, 256GB SSD, Endless OS, En kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$469.10</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/571" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">5 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$484.23</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/572" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
# </h4>
# <p class="description">Lenovo V510 Black, 14" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$485.90</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/573" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
# </h4>
# <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i5-7200U, 4GB, 128GB SSD, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">6 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$487.80</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/574" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
# </h4>
# <p class="description">Lenovo V510 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$488.64</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/575" title="Acer Swift 1 SF113-31 Silver">Acer Swift 1 SF1...</a>
# </h4>
# <p class="description">Acer Swift 1 SF113-31 Silver, 13.3" FHD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$488.78</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/531" title="Dell Vostro 15">Dell Vostro 15</a>
# </h4>
# <p class="description">Dell Vostro 15 (3568) Black, 15.6" FHD, Core i5-7200U, 4GB, 128GB SSD, Radeon R5 M420 2GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">14 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$494.71</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/576" title="Acer Aspire 3 A315-51 Black">Acer Aspire 3 A3...</a>
# </h4>
# <p class="description">Acer Aspire 3 A315-51 Black, 15.6" FHD, Core i3-7100U, 4GB, 500GB + 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$497.17</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/577" title="Dell Vostro 15 (3568) Red">Dell Vostro 15 (...</a>
# </h4>
# <p class="description">Dell Vostro 15 (3568) Red, 15.6" HD, Core i5-7200U, 4GB, 1TB, Radeon R5 M420 2GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$498.23</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/578" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
# </h4>
# <p class="description">Lenovo V510 Black, 15.6" FHD, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">5 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$520.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/527" title="HP 250 G3">HP 250 G3</a>
# </h4>
# <p class="description">15.6", Core i5-4210U, 4GB, 500GB, Windows 8.1</p>
# </div>
# <div class="ratings">
# <p class="pull-right">13 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$564.98</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/532" title="Acer Spin 5">Acer Spin 5</a>
# </h4>
# <p class="description">Acer Spin 5 SP513-51 Black, 13.3" FHD Touch, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">0 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$577.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/529" title="HP 350 G1">HP 350 G1</a>
# </h4>
# <p class="description">15.6", Core i5-4200U, 4GB, 750GB, Radeon HD8670M 2GB, Windows</p>
# </div>
# <div class="ratings">
# <p class="pull-right">10 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$581.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/521" title="Aspire E1-572G">Aspire E1-572G</a>
# </h4>
# <p class="description">15.6", Core i5-4200U, 8GB, 1TB, Radeon R7 M265, Windows 8.1</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$609.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/523" title="Pavilion">Pavilion</a>
# </h4>
# <p class="description">15.6", Core i5-4200U, 6GB, 750GB, Windows 8.1</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$679.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/533" title="Acer Aspire A515-51-5654">Acer Aspire A515...</a>
# </h4>
# <p class="description">Acer Aspire A515-51-5654, Black, 15.6", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$679.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/534" title="Dell Inspiron 15">Dell Inspiron 15</a>
# </h4>
# <p class="description">Dell Inspiron 15 (5567) Fog Gray, 15.6" FHD, Core i5-7200U, 8GB, 1TB, Radeon R7 M445 4GB, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$729.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/535" title="Asus VivoBook S14">Asus VivoBook S1...</a>
# </h4>
# <p class="description">Asus VivoBook S14 (S406UA-BV041T) Starry Grey, 14", Core i5-8250U, 8GB, 256GB SSD, Windows 10 Home, Eng kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$739.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/519" title="ProBook">ProBook</a>
# </h4>
# <p class="description">14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$745.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/524" title="Inspiron 15">Inspiron 15</a>
# </h4>
# <p class="description">Moon Silver, 15.6", Core i7-4510U, 8GB, 1TB, Radeon HD R7 M265 2GB,</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$799.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/536" title="Asus ROG STRIX GL553VD-DM256">Asus ROG STRIX G...</a>
# </h4>
# <p class="description">Asus ROG STRIX GL553VD-DM256, 15.6" FHD, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, No OS</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$809.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/537" title="Acer Nitro 5 AN515-51">Acer Nitro 5 AN5...</a>
# </h4>
# <p class="description">Acer Nitro 5 AN515-51, 15.6" FHD IPS, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">0 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$899.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/538" title="Asus ROG STRIX GL553VD-DM256">Asus ROG STRIX G...</a>
# </h4>
# <p class="description">Asus ROG STRIX GL553VD-DM256, 15.6" FHD, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, No OS + Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$999.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/539" title="Lenovo ThinkPad L570">Lenovo ThinkPad...</a>
# </h4>
# <p class="description">Lenovo ThinkPad L570, 15.6" FHD, Core i7-7500U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">11 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1033.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/522" title="ThinkPad Yoga">ThinkPad Yoga</a>
# </h4>
# <p class="description">12.5" Touch, Core i3-4010U, 4GB, 500GB + 16GB SSD Cache,</p>
# </div>
# <div class="ratings">
# <p class="pull-right">13 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1096.02</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/579" title="Lenovo ThinkPad L460">Lenovo ThinkPad...</a>
# </h4>
# <p class="description">Lenovo ThinkPad L460, 14" FHD IPS, Core i7-6600U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">14 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1098.42</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/580" title="Dell Inspiron 15 (7567) Black">Dell Inspiron 15...</a>
# </h4>
# <p class="description">Dell Inspiron 15 (7567) Black, 15.6" FHD, Core i5-7300HQ, 8GB, 256GB SSD, GeForce GTX 1050 4GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1099.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/581" title="MSI GL72M 7RDX">MSI GL72M 7RDX</a>
# </h4>
# <p class="description">MSI GL72M 7RDX, 17.3" FHD, Core i5-7300HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1099.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/582" title="MSI GL72M 7RDX">MSI GL72M 7RDX</a>
# </h4>
# <p class="description">Asus ROG Strix GL553VD-DM535T, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 2GB, Windows 10 Home, Eng kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">9 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1101.83</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/583" title="Asus ROG Strix GL553VD-DM535T">Asus ROG Strix G...</a>
# </h4>
# <p class="description">Apple MacBook Air 13.3", Core i5 1.8GHz, 8GB, 128GB SSD, Intel HD 4000, RUS</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1102.66</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/584" title="Dell Latitude 5280">Dell Latitude 52...</a>
# </h4>
# <p class="description">Dell Latitude 5280, 12.5" HD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1110.14</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/585" title="Dell Latitude 5480">Dell Latitude 54...</a>
# </h4>
# <p class="description">Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 500GB, Linux + Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1112.91</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/586" title="Lenovo Legion Y520-15IKBM">Lenovo Legion Y5...</a>
# </h4>
# <p class="description">Lenovo Legion Y520-15IKBM, Black, 15.6" FHD IPS, Core i5-7300HQ, 8 GB, 128GB SSD + 2 TB HDD, NVIDIA GeForce GTX 1060 6 GB, FreeDOS + Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1114.55</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/587" title="Toshiba Portege Z30-C-16J Grey">Toshiba Portege...</a>
# </h4>
# <p class="description">Toshiba Portege Z30-C-16J Grey, 13.3" FHD, Core i5-6200U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">0 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# ...
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1281.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/525" title="Dell XPS 13">Dell XPS 13</a>
# </h4>
# <p class="description">13.3" Touch, Core i5-4210U, 8GB, 128GB SSD, Windows 8.1</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1294.74</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/619" title="Toshiba Portege Z30-C-16K Grey">Toshiba Portege...</a>
# </h4>
# <p class="description">Toshiba Portege Z30-C-16K Grey, 13.3" FHD, Core i5-6200U, 8GB, 256GB SSD, 4G, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">6 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1299.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/620" title="MSI GL62VR 7RFX">MSI GL62VR 7RFX</a>
# </h4>
# <p class="description">MSI GL62VR 7RFX, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 256GB SSD, GeForce GTX 1060 3GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">1 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1310.39</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/621" title="Dell Latitude 5480">Dell Latitude 54...</a>
# </h4>
# <p class="description">Dell Latitude 5480, 14" FHD, Core i7-7600U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1311.99</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/520" title="ThinkPad X240">ThinkPad X240</a>
# </h4>
# <p class="description">12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro 64bit</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1326.83</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/622" title="Hewlett Packard ProBook 640 G3">Hewlett Packard...</a>
# </h4>
# <p class="description">Hewlett Packard ProBook 640 G3, 14" FHD, Core i7-7600U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">2 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1333.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/623" title='Apple MacBook Pro 13" Space Gray'>Apple MacBook Pr...</a>
# </h4>
# <p class="description">Apple MacBook Pro 13" Space Gray, Core i5 2.3GHz, 8GB, 128GB SSD, Iris Plus 640, ENG</p>
# </div>
# <div class="ratings">
# <p class="pull-right">0 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1337.28</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/624" title="Dell Latitude 5580">Dell Latitude 55...</a>
# </h4>
# <p class="description">Dell Latitude 5580, 15.6" FHD, Core i7-7600U, 8GB, 256GB SSD, GeForce GT930MX, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">6 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1338.37</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/625" title="Dell Latitude 5480">Dell Latitude 54...</a>
# </h4>
# <p class="description">Dell Latitude 5480, 14" FHD, Core i7-7600U, 8GB, 256GB SSD, Linux + Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">11 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1341.22</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/626" title="Dell Latitude 5580">Dell Latitude 55...</a>
# </h4>
# <p class="description">Dell Latitude 5580, 15.6" FHD, Core i7-7600U, 16GB, 256GB SSD, GeForce GT930MX, Linux</p>
# </div>
# <div class="ratings">
# <p class="pull-right">3 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1347.78</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/627" title='Apple MacBook Air 13"'>Apple MacBook Ai...</a>
# </h4>
# <p class="description">Apple MacBook Air 13", Intel Core i5 1.8GHz, 8GB, 256GB SSD, Intel HD 6000, RUS</p>
# </div>
# <div class="ratings">
# <p class="pull-right">11 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1349.23</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/628" title="Lenovo ThinkPad T470">Lenovo ThinkPad...</a>
# </h4>
# <p class="description">Lenovo ThinkPad T470, 14" FHD IPS, Core i5-7200U, 8GB, 256GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">5 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1362.24</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/629" title="Lenovo ThinkPad Yoga 370 Black">Lenovo ThinkPad...</a>
# </h4>
# <p class="description">Lenovo ThinkPad Yoga 370 Black, 13.3" FHD IPS Touch, Core i5-7200U, 8GB, 256GB SSD, 4G, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">12 reviews</p>
# <p data-rating="2">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1366.32</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/630" title="Toshiba Portege X20W-D-10V Black/Blue">Toshiba Portege...</a>
# </h4>
# <p class="description">Toshiba Portege X20W-D-10V Black/Blue, 12.5" FHD Touch, Core i7-7500U, 8GB, 512GB SSD, Windows 10 Pro</p>
# </div>
# <div class="ratings">
# <p class="pull-right">11 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1381.13</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/631" title="Asus ASUSPRO B9440UA-GV0279R Gray">Asus ASUSPRO B94...</a>
# </h4>
# <p class="description">Asus ASUSPRO B9440UA-GV0279R Gray, 14" FHD, Core i7-7500U, 16GB, 512GB SSD, Windows 10 Pro, Eng kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">4 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1399.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/541" title="Lenovo Legion Y720">Lenovo Legion Y7...</a>
# </h4>
# <p class="description">Lenovo Legion Y720, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 128GB SSD + 2TB HDD, GeForce GTX 1060 6GB, DOS, RGB backlit keyboard</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1399.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/632" title="Asus ROG Strix GL702VM-GC146T">Asus ROG Strix G...</a>
# </h4>
# <p class="description">Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1060 3GB, Windows 10 Home, Eng kbd</p>
# </div>
# <div class="ratings">
# <p class="pull-right">10 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1769.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/542" title="Asus ROG Strix GL702ZC-GC154T">Asus ROG Strix G...</a>
# </h4>
# <p class="description">Asus ROG Strix GL702ZC-GC154T, 17.3" FHD, Ryzen 7 1700, 16GB, 256GB + 1TB HDD, Radeon RX 580 4GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">7 reviews</p>
# <p data-rating="4">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1769.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/543" title="Asus ROG Strix GL702ZC-GC209T">Asus ROG Strix G...</a>
# </h4>
# <p class="description">Asus ROG Strix GL702ZC-GC209T, 17.3" FHD IPS, Ryzen 7 1700, 16GB, 256GB SSD + 1TB HDD, Radeon RX 580 4GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="1">
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# <div class="col-sm-4 col-lg-4 col-md-4">
# <div class="thumbnail">
# <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
# <div class="caption">
# <h4 class="pull-right price">$1799.00</h4>
# <h4>
# <a class="title" href="/test-sites/e-commerce/allinone/product/544" title="Asus ROG Strix SCAR Edition GL503VM-ED115T">Asus ROG Strix S...</a>
# </h4>
# <p class="description">Asus ROG Strix SCAR Edition GL503VM-ED115T, 15.6" FHD 120Hz, Core i7-7700HQ, 16GB, 256GB SSD + 1TB SSHD, GeForce GTX 1060 6GB, Windows 10 Home</p>
# </div>
# <div class="ratings">
# <p class="pull-right">8 reviews</p>
# <p data-rating="3">
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# <span class="glyphicon glyphicon-star"></span>
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="push"></div>
# </div>
# <div class="container-fluid footer" id="layout-footer">
# <div class="container">
# <div class="row">
# <div class="col-md-3">
# <ul>
# <li><p>Products</p></li>
# <li>
# <a href="/">Web Scraper browser extension</a>
# </li>
# <li>
# <a href="/pricing">Web Scraper Cloud</a>
# </li>
# </ul>
# </div>
# <div class="col-md-3">
# <ul>
# <li><p>Company</p></li>
# <li>
# <a href="/about-us">About us</a>
# </li>
# <li>
# <a href="/contact">Contact</a>
# </li>
# <li>
# <a href="/privacy-policy">Website Privacy Policy</a>
# </li>
# <li>
# <a href="/extension-privacy-policy">Browser Extension Privacy Policy</a>
# </li>
# <li>
# <a href="https://webscraper.io/downloads/Web_Scraper_Media_Kit.zip">Media kit</a>
# </li>
# <li><a href="/jobs">Jobs</a></li>
# </ul>
# </div>
# <div class="col-md-3">
# <ul>
# <li><p>Resources</p></li>
# <li><a href="/blog">Blog</a></li>
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/screenshots">Screenshots</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# <li>
# <a href="https://status.webscraper.io/" rel="noopener" target="_blank">Status</a>
# </li>
# </ul>
# </div>
# <div class="col-md-3">
# <ul>
# <li><p>CONTACT US</p></li>
# <li>
# <a href="mailto:info@webscraper.io">info@webscraper.io</a>
# </li>
# <li>Ubelu 5-71,<br/> Adazi, Latvia, LV-2164</li>
# </ul>
# <ul class="smedia">
# <li>
# <a href="https://www.facebook.com/webscraperio/" rel="noopener" target="_blank"><img alt="Web Scraper on Facebook" src="/img/fbicon.png"/></a>
# </li>
# <li>
# <a href="https://twitter.com/webscraperio" rel="noopener" target="_blank"><img alt="Web Scraper on Twitter" src="/img/twicon.png"/></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12">
# <p class="copyright">Copyright &amp;copy 2023
# 					<a href="#">Web Scraper</a> | All rights
# 					reserved</p>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %%
# Access h1 tag
soup.h1
# Out:
# <h1>Test Sites</h1>

# %%
# Access header tag
soup.header
# Access div tag
soup.div
# Out:
# <div class="container">
# <div class="navbar-header">
# <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# </button>
# </a>
# <div class="navbar-brand">
# <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
# </div>
# </div>
# <div class="side-collapse in">
# <nav class="navbar-collapse collapse" id="navbar" role="navigation">
# <ul class="nav navbar-nav navbar-right">
# <li class="hidden">
# <a href="#page-top"></a>
# </li>
# <li>
# <a class="menuitm" href="/">
# <p>Web Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li>
# <a class="menuitm" href="/cloud-scraper">
# <p>Cloud Scraper</p>
# <div class="crta"></div>
# </a>
# </li>
# <li>
# <a class="menuitm" href="/pricing">
# <p>Pricing</p>
# <div class="crta"></div>
# </a>
# </li>
# <li class="dropdown">
# <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
# <p>Learn</p>
# <div class="crta"></div>
# </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/documentation">Documentation</a>
# </li>
# <li>
# <a href="/tutorials">Video Tutorials</a>
# </li>
# <li>
# <a href="/how-to-videos">How to</a>
# </li>
# <li>
# <a href="/test-sites">Test Sites</a>
# </li>
# <li>
# <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
# </li>
# <li>
# <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
# </li>
# </ul>
# </nav>
# </div>
# </div>

# %%
# Access string from nested tags
soup.header.p
# Out:
# <p>Web Scraper</p>

# %%
# Access string from nested tags
soup.header.p
soup.header.p.string
# Out:
# 'Web Scraper'

# %%
# Access ‘a’ tag in <header>
a_start = soup.header.a
a_start
# Access only the attributes using attrs
a_start.attrs
# Out:
# {'data-toggle': 'collapse-side',
#  'data-target': '.side-collapse',
#  'data-target-2': '.side-collapse-container'}

# %%
a_start['data-target']
# Out:
# '.side-collapse'

# %%
a_start['new-attribute'] = "This is the new attribute"
a_start.attrs
a_start
# Out:
# <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side" new-attribute="This is the new attribute">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar top-bar"></span>
# <span class="icon-bar middle-bar"></span>
# <span class="icon-bar bottom-bar"></span>
# </button>
# </a>

# %%
# Searching specific attributes of tags)
soup.find('h4', class_= 'pull-right price')
# Out:
# <h4 class="pull-right price">$295.99</h4>

# %%
# Using find_all
soup.find_all('h4', class_= 'pull-right price')
# Out:
# [<h4 class="pull-right price">$295.99</h4>,
#  <h4 class="pull-right price">$299.00</h4>,
#  <h4 class="pull-right price">$299.00</h4>,
#  <h4 class="pull-right price">$306.99</h4>,
#  <h4 class="pull-right price">$321.94</h4>,
#  <h4 class="pull-right price">$356.49</h4>,
#  <h4 class="pull-right price">$364.46</h4>,
#  <h4 class="pull-right price">$372.70</h4>,
#  <h4 class="pull-right price">$379.94</h4>,
#  <h4 class="pull-right price">$379.95</h4>,
#  <h4 class="pull-right price">$391.48</h4>,
#  <h4 class="pull-right price">$393.88</h4>,
#  <h4 class="pull-right price">$399.00</h4>,
#  <h4 class="pull-right price">$399.99</h4>,
#  <h4 class="pull-right price">$404.23</h4>,
#  <h4 class="pull-right price">$408.98</h4>,
#  <h4 class="pull-right price">$409.63</h4>,
#  <h4 class="pull-right price">$410.46</h4>,
#  <h4 class="pull-right price">$410.66</h4>,
#  <h4 class="pull-right price">$416.99</h4>,
#  <h4 class="pull-right price">$433.30</h4>,
#  <h4 class="pull-right price">$436.29</h4>,
#  <h4 class="pull-right price">$436.29</h4>,
#  <h4 class="pull-right price">$439.73</h4>,
#  <h4 class="pull-right price">$454.62</h4>,
#  <h4 class="pull-right price">$454.73</h4>,
#  <h4 class="pull-right price">$457.38</h4>,
#  <h4 class="pull-right price">$465.95</h4>,
#  <h4 class="pull-right price">$468.56</h4>,
#  <h4 class="pull-right price">$469.10</h4>,
#  <h4 class="pull-right price">$484.23</h4>,
#  <h4 class="pull-right price">$485.90</h4>,
#  <h4 class="pull-right price">$487.80</h4>,
#  <h4 class="pull-right price">$488.64</h4>,
#  <h4 class="pull-right price">$488.78</h4>,
#  <h4 class="pull-right price">$494.71</h4>,
#  <h4 class="pull-right price">$497.17</h4>,
#  <h4 class="pull-right price">$498.23</h4>,
#  <h4 class="pull-right price">$520.99</h4>,
#  <h4 class="pull-right price">$564.98</h4>,
#  <h4 class="pull-right price">$577.99</h4>,
#  <h4 class="pull-right price">$581.99</h4>,
#  <h4 class="pull-right price">$609.99</h4>,
#  <h4 class="pull-right price">$679.00</h4>,
#  <h4 class="pull-right price">$679.00</h4>,
#  <h4 class="pull-right price">$729.00</h4>,
#  <h4 class="pull-right price">$739.99</h4>,
#  <h4 class="pull-right price">$745.99</h4>,
#  <h4 class="pull-right price">$799.00</h4>,
#  <h4 class="pull-right price">$809.00</h4>,
#  <h4 class="pull-right price">$899.00</h4>,
#  <h4 class="pull-right price">$999.00</h4>,
#  <h4 class="pull-right price">$1033.99</h4>,
#  <h4 class="pull-right price">$1096.02</h4>,
#  <h4 class="pull-right price">$1098.42</h4>,
#  <h4 class="pull-right price">$1099.00</h4>,
#  <h4 class="pull-right price">$1099.00</h4>,
#  <h4 class="pull-right price">$1101.83</h4>,
#  <h4 class="pull-right price">$1102.66</h4>,
#  <h4 class="pull-right price">$1110.14</h4>,
#  <h4 class="pull-right price">$1112.91</h4>,
#  <h4 class="pull-right price">$1114.55</h4>,
#  <h4 class="pull-right price">$1123.87</h4>,
#  <h4 class="pull-right price">$1123.87</h4>,
#  <h4 class="pull-right price">$1124.20</h4>,
#  <h4 class="pull-right price">$1133.82</h4>,
#  <h4 class="pull-right price">$1133.91</h4>,
#  <h4 class="pull-right price">$1139.54</h4>,
#  <h4 class="pull-right price">$1140.62</h4>,
#  <h4 class="pull-right price">$1143.40</h4>,
#  <h4 class="pull-right price">$1144.20</h4>,
#  <h4 class="pull-right price">$1144.40</h4>,
#  <h4 class="pull-right price">$1149.00</h4>,
#  <h4 class="pull-right price">$1149.00</h4>,
#  <h4 class="pull-right price">$1149.73</h4>,
#  <h4 class="pull-right price">$1154.04</h4>,
#  <h4 class="pull-right price">$1170.10</h4>,
#  <h4 class="pull-right price">$1178.19</h4>,
#  <h4 class="pull-right price">$1178.99</h4>,
#  <h4 class="pull-right price">$1179.00</h4>,
#  <h4 class="pull-right price">$1187.88</h4>,
#  <h4 class="pull-right price">$1187.98</h4>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <h4 class="pull-right price">$1199.73</h4>,
#  <h4 class="pull-right price">$1203.41</h4>,
#  <h4 class="pull-right price">$1212.16</h4>,
#  <h4 class="pull-right price">$1221.58</h4>,
#  <h4 class="pull-right price">$1223.99</h4>,
#  <h4 class="pull-right price">$1235.49</h4>,
#  <h4 class="pull-right price">$1238.37</h4>,
#  <h4 class="pull-right price">$1239.20</h4>,
#  <h4 class="pull-right price">$1244.99</h4>,
#  <h4 class="pull-right price">$1259.00</h4>,
#  <h4 class="pull-right price">$1260.13</h4>,
#  <h4 class="pull-right price">$1271.06</h4>,
#  <h4 class="pull-right price">$1273.11</h4>,
#  <h4 class="pull-right price">$1281.99</h4>,
#  <h4 class="pull-right price">$1294.74</h4>,
#  <h4 class="pull-right price">$1299.00</h4>,
#  <h4 class="pull-right price">$1310.39</h4>,
#  <h4 class="pull-right price">$1311.99</h4>,
#  <h4 class="pull-right price">$1326.83</h4>,
#  <h4 class="pull-right price">$1333.00</h4>,
#  <h4 class="pull-right price">$1337.28</h4>,
#  <h4 class="pull-right price">$1338.37</h4>,
#  <h4 class="pull-right price">$1341.22</h4>,
#  <h4 class="pull-right price">$1347.78</h4>,
#  <h4 class="pull-right price">$1349.23</h4>,
#  <h4 class="pull-right price">$1362.24</h4>,
#  <h4 class="pull-right price">$1366.32</h4>,
#  <h4 class="pull-right price">$1381.13</h4>,
#  <h4 class="pull-right price">$1399.00</h4>,
#  <h4 class="pull-right price">$1399.00</h4>,
#  <h4 class="pull-right price">$1769.00</h4>,
#  <h4 class="pull-right price">$1769.00</h4>,
#  <h4 class="pull-right price">$1799.00</h4>]

# %%
# Slicing the results of find_all
soup.find_all('h4', class_= 'pull-right price')[2:5]
# Out:
# [<h4 class="pull-right price">$299.00</h4>,
#  <h4 class="pull-right price">$306.99</h4>,
#  <h4 class="pull-right price">$321.94</h4>]

# %%
# Using filter to find multiple tags
soup.find_all(['h4', 'a', 'p'])
soup.find_all(['header', 'div'])
soup.find_all(id = True) # class and id are special attribute so it can be written like this
soup.find_all(class_= True)
# Out:
# [<header class="navbar navbar-fixed-top navbar-static" role="banner">
#  <div class="container">
#  <div class="navbar-header">
#  <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side" new-attribute="This is the new attribute">
#  <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar top-bar"></span>
#  <span class="icon-bar middle-bar"></span>
#  <span class="icon-bar bottom-bar"></span>
#  </button>
#  </a>
#  <div class="navbar-brand">
#  <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
#  </div>
#  </div>
#  <div class="side-collapse in">
#  <nav class="navbar-collapse collapse" id="navbar" role="navigation">
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>
#  <li>
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>
#  <li>
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
#  </li>
#  <li>
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
#  </li>
#  </ul>
#  </nav>
#  </div>
#  </div>
#  </header>,
#  <div class="container">
#  <div class="navbar-header">
#  <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side" new-attribute="This is the new attribute">
#  <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar top-bar"></span>
#  <span class="icon-bar middle-bar"></span>
#  <span class="icon-bar bottom-bar"></span>
#  </button>
#  </a>
#  <div class="navbar-brand">
#  <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
#  </div>
#  </div>
#  <div class="side-collapse in">
#  <nav class="navbar-collapse collapse" id="navbar" role="navigation">
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>
#  <li>
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>
#  <li>
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
#  </li>
#  <li>
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
#  </li>
#  </ul>
#  </nav>
#  </div>
#  </div>,
#  <div class="navbar-header">
#  <a data-target=".side-collapse" data-target-2=".side-collapse-container" data-toggle="collapse-side" new-attribute="This is the new attribute">
#  <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar top-bar"></span>
#  <span class="icon-bar middle-bar"></span>
#  <span class="icon-bar bottom-bar"></span>
#  </button>
#  </a>
#  <div class="navbar-brand">
#  <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
#  </div>
#  </div>,
#  <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle pull-right collapsed" data-target="#navbar" data-target-2=".side-collapse-container" data-target-3=".side-collapse" data-toggle="collapse" type="button">
#  <span class="sr-only">Toggle navigation</span>
#  <span class="icon-bar top-bar"></span>
#  <span class="icon-bar middle-bar"></span>
#  <span class="icon-bar bottom-bar"></span>
#  </button>,
#  <span class="sr-only">Toggle navigation</span>,
#  <span class="icon-bar top-bar"></span>,
#  <span class="icon-bar middle-bar"></span>,
#  <span class="icon-bar bottom-bar"></span>,
#  <div class="navbar-brand">
#  <a href="/"><img alt="Web Scraper" src="/img/logo_white.svg"/></a>
#  </div>,
#  <div class="side-collapse in">
#  <nav class="navbar-collapse collapse" id="navbar" role="navigation">
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>
#  <li>
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>
#  <li>
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
#  </li>
#  <li>
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
#  </li>
#  </ul>
#  </nav>
#  </div>,
#  <nav class="navbar-collapse collapse" id="navbar" role="navigation">
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>
#  <li>
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>
#  <li>
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
#  </li>
#  <li>
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
#  </li>
#  </ul>
#  </nav>,
#  <ul class="nav navbar-nav navbar-right">
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>
#  <li>
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li>
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>
#  </li>
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>
#  <li>
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>
#  </li>
#  <li>
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>
#  </li>
#  </ul>,
#  <li class="hidden">
#  <a href="#page-top"></a>
#  </li>,
#  <a class="menuitm" href="/">
#  <p>Web Scraper</p>
#  <div class="crta"></div>
#  </a>,
#  <div class="crta"></div>,
#  <a class="menuitm" href="/cloud-scraper">
#  <p>Cloud Scraper</p>
#  <div class="crta"></div>
#  </a>,
#  <div class="crta"></div>,
#  <a class="menuitm" href="/pricing">
#  <p>Pricing</p>
#  <div class="crta"></div>
#  </a>,
#  <div class="crta"></div>,
#  <li class="dropdown">
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>
#  </li>,
#  <a class="menuitm dropdown-toggle" data-toggle="dropdown" href="#section3">
#  <p>Learn</p>
#  <div class="crta"></div>
#  </a>,
#  <div class="crta"></div>,
#  <ul class="dropdown-menu">
#  <li>
#  <a href="/documentation">Documentation</a>
#  </li>
#  <li>
#  <a href="/tutorials">Video Tutorials</a>
#  </li>
#  <li>
#  <a href="/how-to-videos">How to</a>
#  </li>
#  <li>
#  <a href="/test-sites">Test Sites</a>
#  </li>
#  <li>
#  <a href="https://forum.webscraper.io/" rel="noopener" target="_blank">Forum</a>
#  </li>
#  </ul>,
#  <a class="btn-menu1 install-extension" href="https://chrome.google.com/webstore/detail/web-scraper/jnhgnonknehpejjnehehllkliplmbmhn?hl=en" target="_blank">Install</a>,
#  <a class="btn-menu2 wide" href="https://cloud.webscraper.io/">Cloud Login</a>,
#  <div class="wrapper">
#  <div class="formenu-here container-fluid">
#  </div>
#  <div class="container-fluid blog-hero">
#  <div class="container">
#  <div class="row">
#  <div class="col-md-12">
#  <h1>Test Sites</h1>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="container test-site">
#  <div class="row">
#  <div class="col-md-3 sidebar">
#  <div class="navbar-default sidebar" role="navigation">
#  <div class="sidebar-nav navbar-collapse">
#  <ul class="nav" id="side-menu">
#  <li>
#  <a href="/test-sites/e-commerce/allinone">Home</a>
#  </li>
#  <li>
#  <a class="category-link" href="/test-sites/e-commerce/allinone/phones">
#  					Phones
#  					<span class="fa arrow"></span>
#  </a>
#  </li>
#  <li class="active">
#  <a class="category-link" href="/test-sites/e-commerce/allinone/computers">
#  					Computers
#  					<span class="fa arrow"></span>
#  </a>
#  <ul class="nav nav-second-level collapse in">
#  <li>
#  <a class="subcategory-link" href="/test-sites/e-commerce/allinone/computers/tablets">
#  							Tablets
#  						</a>
#  </li>
#  <li>
#  <a class="subcategory-link active" href="/test-sites/e-commerce/allinone/computers/laptops">
#  							Laptops
#  						</a>
#  </li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-9">
#  <h1 class="page-header">Computers / Laptops</h1>
#  <div class="row">
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$295.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/545" title="Asus VivoBook X441NA-GA190">Asus VivoBook X4...</a>
#  </h4>
#  <p class="description">Asus VivoBook X441NA-GA190 Chocolate Black, 14", Celeron N3450, 4GB, 128GB SSD, Endless OS, ENG kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$299.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/546" title="Prestigio SmartBook 133S Dark Grey">Prestigio SmartB...</a>
#  </h4>
#  <p class="description">Prestigio SmartBook 133S Dark Grey, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">8 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$299.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/547" title="Prestigio SmartBook 133S Gold">Prestigio SmartB...</a>
#  </h4>
#  <p class="description">Prestigio SmartBook 133S Gold, 13.3" FHD IPS, Celeron N3350 1.1GHz, 4GB, 32GB, Windows 10 Pro + Office 365 1 gadam</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$306.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/517" title="Aspire E1-510">Aspire E1-510</a>
#  </h4>
#  <p class="description">15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$321.94</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/548" title="Lenovo V110-15IAP">Lenovo V110-15IA...</a>
#  </h4>
#  <p class="description">Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$356.49</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/549" title="Lenovo V110-15IAP">Lenovo V110-15IA...</a>
#  </h4>
#  <p class="description">Asus VivoBook 15 X540NA-GQ008T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 500GB, Windows 10 Home, En kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">6 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$364.46</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/550" title="Hewlett Packard 250 G6 Dark Ash Silver">Hewlett Packard...</a>
#  </h4>
#  <p class="description">Hewlett Packard 250 G6 Dark Ash Silver, 15.6" HD, Celeron N3060 1.6GHz, 4GB, 128GB SSD, DOS</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$372.70</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/551" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Celeron N3350 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$379.94</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/552" title="Acer Aspire A315-31-C33J">Acer Aspire A315...</a>
#  </h4>
#  <p class="description">Acer Aspire A315-31-C33J Black 15.6", HD, Celeron N3350, 4GB DDR3L, 128GB, Windows 10 Home, ENG</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">0 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$379.95</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/553" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$391.48</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/554" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">10 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$393.88</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/555" title="Acer Aspire 3 A315-21">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-21, 15.6", AMD A4-9120. 4GB. 128GB SSD, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$399.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/530" title="Asus VivoBook Max">Asus VivoBook Ma...</a>
#  </h4>
#  <p class="description">Asus VivoBook Max X541NA-GQ041 Black Chocolate, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 500GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">4 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$399.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/556" title="Asus VivoBook E502NA-GO022T Dark Blue">Asus VivoBook E5...</a>
#  </h4>
#  <p class="description">Asus VivoBook E502NA-GO022T Dark Blue, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">3 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$404.23</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/557" title="Lenovo ThinkPad E31-80">Lenovo ThinkPad...</a>
#  </h4>
#  <p class="description">Lenovo ThinkPad E31-80, 13.3" HD, Celeron 3855U 1.6GHz, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$408.98</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/558" title="Acer Aspire 3 A315-31 Black">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-31 Black, 15.6" HD, Pentium N4200 1.1GHz, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">10 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$409.63</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/559" title="Lenovo V110-15ISK">Lenovo V110-15IS...</a>
#  </h4>
#  <p class="description">Lenovo V110-15ISK, 15.6" HD, Core i3-6006U, 8GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$410.46</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/560" title="Acer Aspire ES1-732 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-732 Black, 17.3" HD+, Celeron, N3350, 4GB, 1TB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$410.66</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/561" title="Asus VivoBook 15 X540NA-GQ026T">Asus VivoBook 15...</a>
#  </h4>
#  <p class="description">Asus VivoBook 15 X540NA-GQ026T Chocolate Black, 15.6" HD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home, En/Ru kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">4 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$416.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/516" title="Packard 255 G2">Packard 255 G2</a>
#  </h4>
#  <p class="description">15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows 8.1</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$433.30</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/562" title="Asus EeeBook R416NA-FA014T">Asus EeeBook R41...</a>
#  </h4>
#  <p class="description">Asus EeeBook R416NA-FA014T, 14" FHD, Pentium N4200, 4GB, 128GB eMMC, Windows 10 Home, Eng kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">1 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$436.29</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/563" title="Acer Aspire 3 A315-51">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-51, 15.6" HD, Core i3-6006U, 4GB, 1TB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">1 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$436.29</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/564" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 500GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$439.73</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/565" title="Acer Extensa 15 (2540) Black">Acer Extensa 15...</a>
#  </h4>
#  <p class="description">Acer Extensa 15 (2540) Black, 15.6" HD, Core i5-7200U, 4GB, 500GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">6 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$454.62</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/566" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i5-7200U, 4GB, 500GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$454.73</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/567" title="Lenovo V110-15ISK">Lenovo V110-15IS...</a>
#  </h4>
#  <p class="description">Lenovo V110-15ISK, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Pro</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$457.38</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/568" title="Acer Aspire A315-51-33TG">Acer Aspire A315...</a>
#  </h4>
#  <p class="description">Acer Aspire A315-51-33TG, Black 15.6" HD, Core i3-7100U, 4GB DDR4, 128GB SSD, Windows 10 Home, ENG</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$465.95</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/569" title="Lenovo V110-15IKB">Lenovo V110-15IK...</a>
#  </h4>
#  <p class="description">Lenovo V110-15IKB, 15.6" HD, Core i5-7200U, 4GB, 500GB, DOS</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$468.56</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/570" title="Asus VivoBook 15 X540UA-DM260 Chocolate Black">Asus VivoBook 15...</a>
#  </h4>
#  <p class="description">Asus VivoBook 15 X540UA-DM260 Chocolate Black, 15.6" FHD, Core i3-6006U, 4GB, 256GB SSD, Endless OS, En kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">1 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$469.10</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/571" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$484.23</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/572" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
#  </h4>
#  <p class="description">Lenovo V510 Black, 14" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">8 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$485.90</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/573" title="Acer Aspire ES1-572 Black">Acer Aspire ES1-...</a>
#  </h4>
#  <p class="description">Acer Aspire ES1-572 Black, 15.6" HD, Core i5-7200U, 4GB, 128GB SSD, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">6 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$487.80</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/574" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
#  </h4>
#  <p class="description">Lenovo V510 Black, 15.6" HD, Core i3-6006U, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$488.64</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/575" title="Acer Swift 1 SF113-31 Silver">Acer Swift 1 SF1...</a>
#  </h4>
#  <p class="description">Acer Swift 1 SF113-31 Silver, 13.3" FHD, Pentium N4200, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">4 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$488.78</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/531" title="Dell Vostro 15">Dell Vostro 15</a>
#  </h4>
#  <p class="description">Dell Vostro 15 (3568) Black, 15.6" FHD, Core i5-7200U, 4GB, 128GB SSD, Radeon R5 M420 2GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$494.71</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/576" title="Acer Aspire 3 A315-51 Black">Acer Aspire 3 A3...</a>
#  </h4>
#  <p class="description">Acer Aspire 3 A315-51 Black, 15.6" FHD, Core i3-7100U, 4GB, 500GB + 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$497.17</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/577" title="Dell Vostro 15 (3568) Red">Dell Vostro 15 (...</a>
#  </h4>
#  <p class="description">Dell Vostro 15 (3568) Red, 15.6" HD, Core i5-7200U, 4GB, 1TB, Radeon R5 M420 2GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$498.23</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/578" title="Lenovo V510 Black">Lenovo V510 Blac...</a>
#  </h4>
#  <p class="description">Lenovo V510 Black, 15.6" FHD, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Pro</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$520.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/527" title="HP 250 G3">HP 250 G3</a>
#  </h4>
#  <p class="description">15.6", Core i5-4210U, 4GB, 500GB, Windows 8.1</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">13 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$564.98</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/532" title="Acer Spin 5">Acer Spin 5</a>
#  </h4>
#  <p class="description">Acer Spin 5 SP513-51 Black, 13.3" FHD Touch, Core i3-7100U, 4GB, 128GB SSD, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">0 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$577.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/529" title="HP 350 G1">HP 350 G1</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200U, 4GB, 750GB, Radeon HD8670M 2GB, Windows</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">10 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$581.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/521" title="Aspire E1-572G">Aspire E1-572G</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200U, 8GB, 1TB, Radeon R7 M265, Windows 8.1</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$609.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/523" title="Pavilion">Pavilion</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200U, 6GB, 750GB, Windows 8.1</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">4 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$679.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/533" title="Acer Aspire A515-51-5654">Acer Aspire A515...</a>
#  </h4>
#  <p class="description">Acer Aspire A515-51-5654, Black, 15.6", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">9 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$679.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/534" title="Dell Inspiron 15">Dell Inspiron 15</a>
#  </h4>
#  <p class="description">Dell Inspiron 15 (5567) Fog Gray, 15.6" FHD, Core i5-7200U, 8GB, 1TB, Radeon R7 M445 4GB, Linux</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$729.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/535" title="Asus VivoBook S14">Asus VivoBook S1...</a>
#  </h4>
#  <p class="description">Asus VivoBook S14 (S406UA-BV041T) Starry Grey, 14", Core i5-8250U, 8GB, 256GB SSD, Windows 10 Home, Eng kbd</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$739.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/519" title="ProBook">ProBook</a>
#  </h4>
#  <p class="description">14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">8 reviews</p>
#  <p data-rating="4">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$745.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/524" title="Inspiron 15">Inspiron 15</a>
#  </h4>
#  <p class="description">Moon Silver, 15.6", Core i7-4510U, 8GB, 1TB, Radeon HD R7 M265 2GB,</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$799.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/536" title="Asus ROG STRIX GL553VD-DM256">Asus ROG STRIX G...</a>
#  </h4>
#  <p class="description">Asus ROG STRIX GL553VD-DM256, 15.6" FHD, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, No OS</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$809.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/537" title="Acer Nitro 5 AN515-51">Acer Nitro 5 AN5...</a>
#  </h4>
#  <p class="description">Acer Nitro 5 AN515-51, 15.6" FHD IPS, Core i5-7300HQ, 8GB, 1TB, GeForce GTX 1050 2GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">0 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$899.00</h4>
#  <h4>
# ...
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1178.19</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/602" title="Dell Latitude 5580">Dell Latitude 55...</a>
#  </h4>
#  <p class="description">Dell Latitude 5580, 15.6" FHD, Core i5-7300U, 16GB, 256GB SSD, Linux + Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">6 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1178.19</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/602" title="Dell Latitude 5580">Dell Latitude 55...</a>
#  </h4>
#  <p class="description">Dell Latitude 5580, 15.6" FHD, Core i5-7300U, 16GB, 256GB SSD, Linux + Windows 10 Home</p>
#  </div>,
#  <h4 class="pull-right price">$1178.19</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/602" title="Dell Latitude 5580">Dell Latitude 55...</a>,
#  <p class="description">Dell Latitude 5580, 15.6" FHD, Core i5-7300U, 16GB, 256GB SSD, Linux + Windows 10 Home</p>,
#  <div class="ratings">
#  <p class="pull-right">6 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">6 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1178.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/518" title="ThinkPad T540p">ThinkPad T540p</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1178.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/518" title="ThinkPad T540p">ThinkPad T540p</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1178.99</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/518" title="ThinkPad T540p">ThinkPad T540p</a>
#  </h4>
#  <p class="description">15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit</p>
#  </div>,
#  <h4 class="pull-right price">$1178.99</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/518" title="ThinkPad T540p">ThinkPad T540p</a>,
#  <p class="description">15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit</p>,
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">2 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1179.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/603" title="MSI GS63 7RD Stealth">MSI GS63 7RD Ste...</a>
#  </h4>
#  <p class="description">MSI GS63 7RD Stealth, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, DOS + Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1179.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/603" title="MSI GS63 7RD Stealth">MSI GS63 7RD Ste...</a>
#  </h4>
#  <p class="description">MSI GS63 7RD Stealth, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, DOS + Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1179.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/603" title="MSI GS63 7RD Stealth">MSI GS63 7RD Ste...</a>
#  </h4>
#  <p class="description">MSI GS63 7RD Stealth, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, DOS + Windows 10 Home</p>
#  </div>,
#  <h4 class="pull-right price">$1179.00</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/603" title="MSI GS63 7RD Stealth">MSI GS63 7RD Ste...</a>,
#  <p class="description">MSI GS63 7RD Stealth, 15.6" FHD IPS, Core i7-7700HQ, 8GB, 256GB SSD, GeForce GTX 1050 2GB, DOS + Windows 10 Home</p>,
#  <div class="ratings">
#  <p class="pull-right">2 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">2 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1187.88</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/604" title="Dell Latitude 5480">Dell Latitude 54...</a>
#  </h4>
#  <p class="description">Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1187.88</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/604" title="Dell Latitude 5480">Dell Latitude 54...</a>
#  </h4>
#  <p class="description">Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1187.88</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/604" title="Dell Latitude 5480">Dell Latitude 54...</a>
#  </h4>
#  <p class="description">Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro</p>
#  </div>,
#  <h4 class="pull-right price">$1187.88</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/604" title="Dell Latitude 5480">Dell Latitude 54...</a>,
#  <p class="description">Dell Latitude 5480, 14" FHD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro</p>,
#  <div class="ratings">
#  <p class="pull-right">5 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">5 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1187.98</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/605" title="Acer Predator Helios 300 (PH317-51)">Acer Predator He...</a>
#  </h4>
#  <p class="description">Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1187.98</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/605" title="Acer Predator Helios 300 (PH317-51)">Acer Predator He...</a>
#  </h4>
#  <p class="description">Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1187.98</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/605" title="Acer Predator Helios 300 (PH317-51)">Acer Predator He...</a>
#  </h4>
#  <p class="description">Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home</p>
#  </div>,
#  <h4 class="pull-right price">$1187.98</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/605" title="Acer Predator Helios 300 (PH317-51)">Acer Predator He...</a>,
#  <p class="description">Acer Predator Helios 300 (PH317-51), 17.3" FHD IPS, Core i7-7700HQ. 8GB, 128GB SSD +1TB, GeForce GTX 1050Ti 4GB, Linux + Windows 10 Home</p>,
#  <div class="ratings">
#  <p class="pull-right">14 reviews</p>
#  <p data-rating="3">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">14 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/606" title="MSI GL62M 7REX">MSI GL62M 7REX</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/606" title="MSI GL62M 7REX">MSI GL62M 7REX</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/606" title="MSI GL62M 7REX">MSI GL62M 7REX</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/606" title="MSI GL62M 7REX">MSI GL62M 7REX</a>,
#  <p class="description">MSI GL62M 7REX, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>,
#  <div class="ratings">
#  <p class="pull-right">7 reviews</p>
#  <p data-rating="1">
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">7 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  <div class="col-sm-4 col-lg-4 col-md-4">
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/607" title="MSI GL62M 7REX2">MSI GL62M 7REX2</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX2, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="thumbnail">
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/607" title="MSI GL62M 7REX2">MSI GL62M 7REX2</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX2, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>
#  </div>,
#  <img alt="item" class="img-responsive" src="/images/test-sites/e-commerce/items/cart2.png"/>,
#  <div class="caption">
#  <h4 class="pull-right price">$1199.00</h4>
#  <h4>
#  <a class="title" href="/test-sites/e-commerce/allinone/product/607" title="MSI GL62M 7REX2">MSI GL62M 7REX2</a>
#  </h4>
#  <p class="description">MSI GL62M 7REX2, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>
#  </div>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <a class="title" href="/test-sites/e-commerce/allinone/product/607" title="MSI GL62M 7REX2">MSI GL62M 7REX2</a>,
#  <p class="description">MSI GL62M 7REX2, 15.6" FHD, Core i7-7700HQ, 8GB, 1TB + 128GB SSD, GeForce GTX 1050 Ti 2GB, Windows 10 Home</p>,
#  <div class="ratings">
#  <p class="pull-right">12 reviews</p>
#  <p data-rating="2">
#  <span class="glyphicon glyphicon-star"></span>
#  <span class="glyphicon glyphicon-star"></span>
#  </p>
#  </div>,
#  <p class="pull-right">12 reviews</p>,
#  <span class="glyphicon glyphicon-star"></span>,
#  ...]

# %%
# Filter by name
name = soup.find_all('a', class_='title')
# Filter by price
price = soup.find_all('h4', class_ = 'pull-right price')
# Filter by reviews
reviews = soup.find_all('p', class_ = 'pull-right')
# Filter by description
description = soup.find_all('p', class_ ='description')

# %%
price
# Out:
# [<h4 class="pull-right price">$295.99</h4>,
#  <h4 class="pull-right price">$299.00</h4>,
#  <h4 class="pull-right price">$299.00</h4>,
#  <h4 class="pull-right price">$306.99</h4>,
#  <h4 class="pull-right price">$321.94</h4>,
#  <h4 class="pull-right price">$356.49</h4>,
#  <h4 class="pull-right price">$364.46</h4>,
#  <h4 class="pull-right price">$372.70</h4>,
#  <h4 class="pull-right price">$379.94</h4>,
#  <h4 class="pull-right price">$379.95</h4>,
#  <h4 class="pull-right price">$391.48</h4>,
#  <h4 class="pull-right price">$393.88</h4>,
#  <h4 class="pull-right price">$399.00</h4>,
#  <h4 class="pull-right price">$399.99</h4>,
#  <h4 class="pull-right price">$404.23</h4>,
#  <h4 class="pull-right price">$408.98</h4>,
#  <h4 class="pull-right price">$409.63</h4>,
#  <h4 class="pull-right price">$410.46</h4>,
#  <h4 class="pull-right price">$410.66</h4>,
#  <h4 class="pull-right price">$416.99</h4>,
#  <h4 class="pull-right price">$433.30</h4>,
#  <h4 class="pull-right price">$436.29</h4>,
#  <h4 class="pull-right price">$436.29</h4>,
#  <h4 class="pull-right price">$439.73</h4>,
#  <h4 class="pull-right price">$454.62</h4>,
#  <h4 class="pull-right price">$454.73</h4>,
#  <h4 class="pull-right price">$457.38</h4>,
#  <h4 class="pull-right price">$465.95</h4>,
#  <h4 class="pull-right price">$468.56</h4>,
#  <h4 class="pull-right price">$469.10</h4>,
#  <h4 class="pull-right price">$484.23</h4>,
#  <h4 class="pull-right price">$485.90</h4>,
#  <h4 class="pull-right price">$487.80</h4>,
#  <h4 class="pull-right price">$488.64</h4>,
#  <h4 class="pull-right price">$488.78</h4>,
#  <h4 class="pull-right price">$494.71</h4>,
#  <h4 class="pull-right price">$497.17</h4>,
#  <h4 class="pull-right price">$498.23</h4>,
#  <h4 class="pull-right price">$520.99</h4>,
#  <h4 class="pull-right price">$564.98</h4>,
#  <h4 class="pull-right price">$577.99</h4>,
#  <h4 class="pull-right price">$581.99</h4>,
#  <h4 class="pull-right price">$609.99</h4>,
#  <h4 class="pull-right price">$679.00</h4>,
#  <h4 class="pull-right price">$679.00</h4>,
#  <h4 class="pull-right price">$729.00</h4>,
#  <h4 class="pull-right price">$739.99</h4>,
#  <h4 class="pull-right price">$745.99</h4>,
#  <h4 class="pull-right price">$799.00</h4>,
#  <h4 class="pull-right price">$809.00</h4>,
#  <h4 class="pull-right price">$899.00</h4>,
#  <h4 class="pull-right price">$999.00</h4>,
#  <h4 class="pull-right price">$1033.99</h4>,
#  <h4 class="pull-right price">$1096.02</h4>,
#  <h4 class="pull-right price">$1098.42</h4>,
#  <h4 class="pull-right price">$1099.00</h4>,
#  <h4 class="pull-right price">$1099.00</h4>,
#  <h4 class="pull-right price">$1101.83</h4>,
#  <h4 class="pull-right price">$1102.66</h4>,
#  <h4 class="pull-right price">$1110.14</h4>,
#  <h4 class="pull-right price">$1112.91</h4>,
#  <h4 class="pull-right price">$1114.55</h4>,
#  <h4 class="pull-right price">$1123.87</h4>,
#  <h4 class="pull-right price">$1123.87</h4>,
#  <h4 class="pull-right price">$1124.20</h4>,
#  <h4 class="pull-right price">$1133.82</h4>,
#  <h4 class="pull-right price">$1133.91</h4>,
#  <h4 class="pull-right price">$1139.54</h4>,
#  <h4 class="pull-right price">$1140.62</h4>,
#  <h4 class="pull-right price">$1143.40</h4>,
#  <h4 class="pull-right price">$1144.20</h4>,
#  <h4 class="pull-right price">$1144.40</h4>,
#  <h4 class="pull-right price">$1149.00</h4>,
#  <h4 class="pull-right price">$1149.00</h4>,
#  <h4 class="pull-right price">$1149.73</h4>,
#  <h4 class="pull-right price">$1154.04</h4>,
#  <h4 class="pull-right price">$1170.10</h4>,
#  <h4 class="pull-right price">$1178.19</h4>,
#  <h4 class="pull-right price">$1178.99</h4>,
#  <h4 class="pull-right price">$1179.00</h4>,
#  <h4 class="pull-right price">$1187.88</h4>,
#  <h4 class="pull-right price">$1187.98</h4>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <h4 class="pull-right price">$1199.00</h4>,
#  <h4 class="pull-right price">$1199.73</h4>,
#  <h4 class="pull-right price">$1203.41</h4>,
#  <h4 class="pull-right price">$1212.16</h4>,
#  <h4 class="pull-right price">$1221.58</h4>,
#  <h4 class="pull-right price">$1223.99</h4>,
#  <h4 class="pull-right price">$1235.49</h4>,
#  <h4 class="pull-right price">$1238.37</h4>,
#  <h4 class="pull-right price">$1239.20</h4>,
#  <h4 class="pull-right price">$1244.99</h4>,
#  <h4 class="pull-right price">$1259.00</h4>,
#  <h4 class="pull-right price">$1260.13</h4>,
#  <h4 class="pull-right price">$1271.06</h4>,
#  <h4 class="pull-right price">$1273.11</h4>,
#  <h4 class="pull-right price">$1281.99</h4>,
#  <h4 class="pull-right price">$1294.74</h4>,
#  <h4 class="pull-right price">$1299.00</h4>,
#  <h4 class="pull-right price">$1310.39</h4>,
#  <h4 class="pull-right price">$1311.99</h4>,
#  <h4 class="pull-right price">$1326.83</h4>,
#  <h4 class="pull-right price">$1333.00</h4>,
#  <h4 class="pull-right price">$1337.28</h4>,
#  <h4 class="pull-right price">$1338.37</h4>,
#  <h4 class="pull-right price">$1341.22</h4>,
#  <h4 class="pull-right price">$1347.78</h4>,
#  <h4 class="pull-right price">$1349.23</h4>,
#  <h4 class="pull-right price">$1362.24</h4>,
#  <h4 class="pull-right price">$1366.32</h4>,
#  <h4 class="pull-right price">$1381.13</h4>,
#  <h4 class="pull-right price">$1399.00</h4>,
#  <h4 class="pull-right price">$1399.00</h4>,
#  <h4 class="pull-right price">$1769.00</h4>,
#  <h4 class="pull-right price">$1769.00</h4>,
#  <h4 class="pull-right price">$1799.00</h4>]

# %%
# Try to call price
price1 = soup.find('h4', class_ = 'pull-right price')
price1.text
# Out:
# '$295.99'

# %%
# Create for loop to make string from find_all list
product_name_list = []
for i in name:
 name = i.text
 product_name_list.append(name)
price_list = []
for i in price:
 price = i.text
 price_list.append(price)

review_list = []
for i in reviews:
 rev = i.text
 review_list.append(rev)

description_list = []
for i in description:
 desc = i.text
 description_list.append(desc)

# %%
# Create dataframe
# Import library
import pandas as pd
table = pd.DataFrame({'Product Name':product_name_list,
 'Price': price_list,
 'Reviews':review_list,
 'Description':description_list})

# %%
table
# Out:
#             Product Name     Price     Reviews  \
# 0    Asus VivoBook X4...   $295.99  14 reviews
# 1    Prestigio SmartB...   $299.00   8 reviews
# 2    Prestigio SmartB...   $299.00  12 reviews
# 3          Aspire E1-510   $306.99   2 reviews
# 4    Lenovo V110-15IA...   $321.94   5 reviews
# ..                   ...       ...         ...
# 112  Lenovo Legion Y7...  $1399.00   8 reviews
# 113  Asus ROG Strix G...  $1399.00  10 reviews
# 114  Asus ROG Strix G...  $1769.00   7 reviews
# 115  Asus ROG Strix G...  $1769.00   8 reviews
# 116  Asus ROG Strix S...  $1799.00   8 reviews
#
#                                            Description
# 0    Asus VivoBook X441NA-GA190 Chocolate Black, 14...
# 1    Prestigio SmartBook 133S Dark Grey, 13.3" FHD ...
# 2    Prestigio SmartBook 133S Gold, 13.3" FHD IPS, ...
# 3      15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
# 4    Lenovo V110-15IAP, 15.6" HD, Celeron N3350 1.1...
# ..                                                 ...
# 112  Lenovo Legion Y720, 15.6" FHD IPS, Core i7-770...
# 113  Asus ROG Strix GL702VM-GC146T, 17.3" FHD, Core...
# 114  Asus ROG Strix GL702ZC-GC154T, 17.3" FHD, Ryze...
# 115  Asus ROG Strix GL702ZC-GC209T, 17.3" FHD IPS, ...
# 116  Asus ROG Strix SCAR Edition GL503VM-ED115T, 15...
#
# [117 rows x 4 columns]
